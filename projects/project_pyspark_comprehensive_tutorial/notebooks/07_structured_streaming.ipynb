# %% [markdown]
# # Module 7: PySpark Structured Streaming
# *Real-Time Data Processing and Live Analytics*
#
# ## Learning Objectives
# By the end of this module, you will master:
#
# **Streaming Fundamentals**
# - Understanding Structured Streaming concepts and architecture
# - Stream processing vs batch processing paradigms
# - Trigger types and processing semantics
# - Handling late-arriving data with watermarks
#
# **Real-Time Processing Patterns**
# - Stateless and stateful transformations on streams
# - Time-based windowing operations (tumbling, sliding, session)
# - Stream-to-stream and stream-to-static joins
# - Aggregations over unbounded data
#
# **Production Streaming**
# - Fault tolerance and exactly-once processing
# - Checkpointing and recovery mechanisms
# - Monitoring streaming queries and performance tuning
# - Integration with external systems (Kafka, databases, files)
#
# **Real-World Applications**
# - Real-time analytics dashboards
# - Live ML model serving and predictions
# - Event-driven architecture patterns
# - Continuous ETL pipelines
#
# ---
#
# ## Module Structure
# 1. **Streaming Setup & Sources** - Environment and data source configuration
# 2. **Basic Stream Processing** - Transformations and simple aggregations
# 3. **Windowing & Time Operations** - Time-based analytics patterns
# 4. **Stateful Operations** - Complex aggregations and joins
# 5. **Real-Time ML Integration** - Apply trained models to streams
# 6. **Production Patterns** - Monitoring, fault tolerance, and deployment

# %%
# Module 7: Structured Streaming Setup
print("Setting up PySpark Structured Streaming Environment...")

import os
import time
import random
import json
from datetime import datetime, timedelta
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.streaming import StreamingQuery

# Configure Spark for Streaming workloads
spark = SparkSession.builder \
    .appName("PySpark-Structured-Streaming") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .config("spark.sql.streaming.checkpointLocation", "/tmp/streaming-checkpoints") \
    .config("spark.sql.streaming.forceDeleteTempCheckpointLocation", "true") \
    .config("spark.default.parallelism", "4") \
    .config("spark.sql.shuffle.partitions", "4") \
    .getOrCreate()

# Set log level to reduce noise
spark.sparkContext.setLogLevel("WARN")

print("Structured Streaming Session Created")
print("Spark Version: {}".format(spark.version))
print("Streaming checkpoint location: /tmp/streaming-checkpoints")

# Display streaming-specific configurations
print("\nStructured Streaming Configuration:")
streaming_configs = [
    "spark.sql.adaptive.enabled",
    "spark.sql.streaming.checkpointLocation",
    "spark.sql.streaming.forceDeleteTempCheckpointLocation"
]

for config in streaming_configs:
    value = spark.conf.get(config, "Not Set")
    print("   {}: {}".format(config, value))

print("\nStructured Streaming environment ready!")
print("Ready for real-time data processing and analytics")
# Out:
# Setting up PySpark Structured Streaming Environment...
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/08/25 23:39:47 WARN Utils: Your hostname, Sanjeevas-iMac.local, resolves to a loopback address: 127.0.0.1; using 192.168.12.128 instead (on interface en1)
# 25/08/25 23:39:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/08/25 23:39:47 WARN Utils: Your hostname, Sanjeevas-iMac.local, resolves to a loopback address: 127.0.0.1; using 192.168.12.128 instead (on interface en1)
# 25/08/25 23:39:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/25 23:39:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/08/25 23:39:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4045. Attempting port 4046.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# 25/08/25 23:39:48 WARN Utils: Service 'SparkUI' could not bind on port 4045. Attempting port 4046.
# Structured Streaming Session Created
# Spark Version: 4.0.0
# Streaming checkpoint location: /tmp/streaming-checkpoints
#
# Structured Streaming Configuration:
#    spark.sql.adaptive.enabled: true
#    spark.sql.streaming.checkpointLocation: /tmp/streaming-checkpoints
#    spark.sql.streaming.forceDeleteTempCheckpointLocation: true
#
# Structured Streaming environment ready!
# Ready for real-time data processing and analytics
#    spark.sql.adaptive.enabled: true
#    spark.sql.streaming.checkpointLocation: /tmp/streaming-checkpoints
#    spark.sql.streaming.forceDeleteTempCheckpointLocation: true
#
# Structured Streaming environment ready!
# Ready for real-time data processing and analytics

# %%
# Generate Real-Time Sensor Data Stream
print("Creating streaming data sources...")

import threading
import json
import os
import builtins  # Fix function name conflicts with PySpark
from datetime import datetime, timedelta
import random
import time

# Create directories for streaming data
streaming_dir = "/tmp/streaming_data"
sensor_dir = f"{streaming_dir}/sensor_data"
os.makedirs(sensor_dir, exist_ok=True)

print(f"Streaming data directory: {streaming_dir}")

# Sensor data generator function
def generate_sensor_data():
    """Generate realistic IoT sensor data for streaming"""
    
    # Define sensor locations (major cities)
    sensor_locations = [
        {"sensor_id": "NYC_001", "city": "New York", "lat": 40.7128, "lon": -74.0060, "type": "air_quality"},
        {"sensor_id": "LA_002", "city": "Los Angeles", "lat": 34.0522, "lon": -118.2437, "type": "air_quality"},
        {"sensor_id": "CHI_003", "city": "Chicago", "lat": 41.8781, "lon": -87.6298, "type": "weather"},
        {"sensor_id": "HOU_004", "city": "Houston", "lat": 29.7604, "lon": -95.3698, "type": "weather"},
        {"sensor_id": "PHX_005", "city": "Phoenix", "lat": 33.4484, "lon": -112.0740, "type": "air_quality"},
        {"sensor_id": "SF_006", "city": "San Francisco", "lat": 37.7749, "lon": -122.4194, "type": "weather"},
        {"sensor_id": "SEA_007", "city": "Seattle", "lat": 47.6062, "lon": -122.3321, "type": "air_quality"},
        {"sensor_id": "MIA_008", "city": "Miami", "lat": 25.7617, "lon": -80.1918, "type": "weather"}
    ]
    
    base_time = datetime.now()
    
    for i in range(50):  # Generate 50 initial records
        for sensor in sensor_locations:
            timestamp = base_time + timedelta(seconds=i*2)  # Every 2 seconds
            
            if sensor["type"] == "air_quality":
                reading = {
                    "timestamp": timestamp.strftime("%Y-%m-%d %H:%M:%S"),
                    "sensor_id": sensor["sensor_id"],
                    "sensor_type": "air_quality",
                    "city": sensor["city"],
                    "latitude": sensor["lat"],
                    "longitude": sensor["lon"],
                    "pm25": builtins.round(random.uniform(5.0, 150.0), 2),
                    "pm10": builtins.round(random.uniform(10.0, 200.0), 2),
                    "o3": builtins.round(random.uniform(20.0, 180.0), 2),
                    "no2": builtins.round(random.uniform(10.0, 100.0), 2),
                    "temperature": builtins.round(random.uniform(-10.0, 45.0), 1),
                    "humidity": builtins.round(random.uniform(20.0, 95.0), 1)
                }
            else:  # weather sensor
                reading = {
                    "timestamp": timestamp.strftime("%Y-%m-%d %H:%M:%S"),
                    "sensor_id": sensor["sensor_id"],
                    "sensor_type": "weather", 
                    "city": sensor["city"],
                    "latitude": sensor["lat"],
                    "longitude": sensor["lon"],
                    "temperature": builtins.round(random.uniform(-10.0, 45.0), 1),
                    "humidity": builtins.round(random.uniform(20.0, 95.0), 1),
                    "pressure": builtins.round(random.uniform(980.0, 1040.0), 1),
                    "wind_speed": builtins.round(random.uniform(0.0, 25.0), 1),
                    "wind_direction": random.randint(0, 359),
                    "precipitation": builtins.round(random.uniform(0.0, 10.0), 2)
                }
            
            yield reading

# Generate initial batch of data
print("Generating initial sensor data...")
data_generator = generate_sensor_data()
initial_records = []

for i, record in enumerate(data_generator):
    initial_records.append(record)
    if i >= 100:  # Generate 100+ initial records
        break

print(f"Generated {len(initial_records)} initial sensor records")

# Save initial data to see structure
sample_file = f"{sensor_dir}/initial_sample.json"
with open(sample_file, 'w') as f:
    for record in initial_records[:10]:
        f.write(json.dumps(record) + '\n')

print(f"Sample data saved to: {sample_file}")
print("\nSample sensor reading:")
print(json.dumps(initial_records[0], indent=2))
# Out:
# Creating streaming data sources...
# Streaming data directory: /tmp/streaming_data
# Generating initial sensor data...
# Generated 101 initial sensor records
# Sample data saved to: /tmp/streaming_data/sensor_data/initial_sample.json
#
# Sample sensor reading:
# {
#   "timestamp": "2025-08-25 23:39:50",
#   "sensor_id": "NYC_001",
#   "sensor_type": "air_quality",
#   "city": "New York",
#   "latitude": 40.7128,
#   "longitude": -74.006,
#   "pm25": 111.25,
#   "pm10": 194.01,
#   "o3": 54.47,
#   "no2": 47.02,
#   "temperature": 12.3,
#   "humidity": 53.1
# }

# %%
# Create Streaming Data Source
print("Setting up streaming data source...")

# Define schema for sensor data
sensor_schema = StructType([
    StructField("timestamp", StringType(), True),
    StructField("sensor_id", StringType(), True),
    StructField("sensor_type", StringType(), True),
    StructField("city", StringType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
    # Air quality sensors
    StructField("pm25", DoubleType(), True),
    StructField("pm10", DoubleType(), True),
    StructField("o3", DoubleType(), True),
    StructField("no2", DoubleType(), True),
    # Common weather fields
    StructField("temperature", DoubleType(), True),
    StructField("humidity", DoubleType(), True),
    # Weather-specific fields
    StructField("pressure", DoubleType(), True),
    StructField("wind_speed", DoubleType(), True),
    StructField("wind_direction", IntegerType(), True),
    StructField("precipitation", DoubleType(), True)
])

print("Schema defined for sensor data")

# Create a streaming DataFrame reading from JSON files
streaming_df = spark \
    .readStream \
    .format("json") \
    .schema(sensor_schema) \
    .option("maxFilesPerTrigger", 1) \
    .load(sensor_dir)

print("Streaming DataFrame created")
print("Reading from directory: {}".format(sensor_dir))

# Add derived columns for streaming analytics
enriched_stream = streaming_df \
    .withColumn("event_time", to_timestamp(col("timestamp"), "yyyy-MM-dd HH:mm:ss")) \
    .withColumn("processing_time", current_timestamp()) \
    .withColumn("year", year(col("event_time"))) \
    .withColumn("month", month(col("event_time"))) \
    .withColumn("day", dayofmonth(col("event_time"))) \
    .withColumn("hour", hour(col("event_time"))) \
    .withColumn("minute", minute(col("event_time"))) \
    .filter(col("sensor_id").isNotNull()) \
    .filter(col("event_time").isNotNull())

print("Enhanced streaming DataFrame with time columns")
print("\nStream Schema:")
enriched_stream.printSchema()
# Out:
# Setting up streaming data source...
# Schema defined for sensor data
# Streaming DataFrame created
# Reading from directory: /tmp/streaming_data/sensor_data
# Enhanced streaming DataFrame with time columns
#
# Stream Schema:
# root
#  |-- timestamp: string (nullable = true)
#  |-- sensor_id: string (nullable = true)
#  |-- sensor_type: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- pm25: double (nullable = true)
#  |-- pm10: double (nullable = true)
#  |-- o3: double (nullable = true)
#  |-- no2: double (nullable = true)
#  |-- temperature: double (nullable = true)
#  |-- humidity: double (nullable = true)
#  |-- pressure: double (nullable = true)
#  |-- wind_speed: double (nullable = true)
#  |-- wind_direction: integer (nullable = true)
#  |-- precipitation: double (nullable = true)
#  |-- event_time: timestamp (nullable = true)
#  |-- processing_time: timestamp (nullable = false)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- minute: integer (nullable = true)
#
# Streaming DataFrame created
# Reading from directory: /tmp/streaming_data/sensor_data
# Enhanced streaming DataFrame with time columns
#
# Stream Schema:
# root
#  |-- timestamp: string (nullable = true)
#  |-- sensor_id: string (nullable = true)
#  |-- sensor_type: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- pm25: double (nullable = true)
#  |-- pm10: double (nullable = true)
#  |-- o3: double (nullable = true)
#  |-- no2: double (nullable = true)
#  |-- temperature: double (nullable = true)
#  |-- humidity: double (nullable = true)
#  |-- pressure: double (nullable = true)
#  |-- wind_speed: double (nullable = true)
#  |-- wind_direction: integer (nullable = true)
#  |-- precipitation: double (nullable = true)
#  |-- event_time: timestamp (nullable = true)
#  |-- processing_time: timestamp (nullable = false)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- minute: integer (nullable = true)

# %%
# Live Data Simulator
print("Creating live data simulator...")

def continuous_data_writer():
    """Continuously write new sensor data files for streaming"""
    import time
    import uuid
    
    file_counter = 0
    
    while True:
        try:
            # Generate new batch of sensor readings
            current_time = datetime.now()
            batch_data = []
            
            # Generate readings for each sensor
            sensor_locations = [
                {"sensor_id": "NYC_001", "city": "New York", "lat": 40.7128, "lon": -74.0060, "type": "air_quality"},
                {"sensor_id": "LA_002", "city": "Los Angeles", "lat": 34.0522, "lon": -118.2437, "type": "air_quality"},
                {"sensor_id": "CHI_003", "city": "Chicago", "lat": 41.8781, "lon": -87.6298, "type": "weather"},
                {"sensor_id": "HOU_004", "city": "Houston", "lat": 29.7604, "lon": -95.3698, "type": "weather"},
                {"sensor_id": "PHX_005", "city": "Phoenix", "lat": 33.4484, "lon": -112.0740, "type": "air_quality"},
                {"sensor_id": "SF_006", "city": "San Francisco", "lat": 37.7749, "lon": -122.4194, "type": "weather"}
            ]
            
            for sensor in sensor_locations:
                # Add some realistic time variance (±30 seconds)
                reading_time = current_time + timedelta(seconds=random.randint(-30, 30))
                
                if sensor["type"] == "air_quality":
                    reading = {
                        "timestamp": reading_time.strftime("%Y-%m-%d %H:%M:%S"),
                        "sensor_id": sensor["sensor_id"],
                        "sensor_type": "air_quality",
                        "city": sensor["city"],
                        "latitude": sensor["lat"],
                        "longitude": sensor["lon"],
                        "pm25": builtins.round(random.uniform(8.0, 120.0), 2),
                        "pm10": builtins.round(random.uniform(15.0, 180.0), 2),
                        "o3": builtins.round(random.uniform(25.0, 160.0), 2),
                        "no2": builtins.round(random.uniform(15.0, 90.0), 2),
                        "temperature": builtins.round(random.uniform(-5.0, 40.0), 1),
                        "humidity": builtins.round(random.uniform(25.0, 90.0), 1)
                    }
                else:  # weather sensor
                    reading = {
                        "timestamp": reading_time.strftime("%Y-%m-%d %H:%M:%S"),
                        "sensor_id": sensor["sensor_id"],
                        "sensor_type": "weather",
                        "city": sensor["city"],
                        "latitude": sensor["lat"],
                        "longitude": sensor["lon"],
                        "temperature": builtins.round(random.uniform(-5.0, 40.0), 1),
                        "humidity": builtins.round(random.uniform(25.0, 90.0), 1),
                        "pressure": builtins.round(random.uniform(985.0, 1035.0), 1),
                        "wind_speed": builtins.round(random.uniform(0.5, 20.0), 1),
                        "wind_direction": random.randint(0, 359),
                        "precipitation": builtins.round(random.uniform(0.0, 8.0), 2)
                    }
                
                batch_data.append(reading)
            
            # Write batch to new file
            file_counter += 1
            batch_file = f"{sensor_dir}/sensor_batch_{file_counter:04d}_{int(time.time())}.json"
            
            with open(batch_file, 'w') as f:
                for record in batch_data:
                    f.write(json.dumps(record) + '\n')
            
            print(f"Written batch {file_counter}: {len(batch_data)} records to {os.path.basename(batch_file)}")
            
            # Wait 5 seconds between batches
            time.sleep(5)
            
        except Exception as e:
            print(f"Data generator error: {e}")
            break

# Start data generator in background thread
data_thread = threading.Thread(target=continuous_data_writer, daemon=True)
data_thread.start()

print("Live data simulator started!")
print("Writing new sensor batches every 5 seconds to: {}".format(sensor_dir))
print("Use this for real-time streaming analytics")

# Wait a moment to let first batch generate
time.sleep(3)
print("\nFirst batch should be generating...")
# Out:
# Creating live data simulator...
# Live data simulator started!
# Writing new sensor batches every 5 seconds to: /tmp/streaming_data/sensor_data
# Use this for real-time streaming analytics
# Written batch 1: 6 records to sensor_batch_0001_1756180439.json
#
# First batch should be generating...
#
# First batch should be generating...
# Written batch 2: 6 records to sensor_batch_0002_1756180444.json
# Written batch 3: 6 records to sensor_batch_0003_1756180449.json
# Written batch 3: 6 records to sensor_batch_0003_1756180449.json
# Written batch 4: 6 records to sensor_batch_0004_1756180454.json
# Written batch 4: 6 records to sensor_batch_0004_1756180454.json
# Written batch 5: 6 records to sensor_batch_0005_1756180459.json
# Written batch 5: 6 records to sensor_batch_0005_1756180459.json
# Written batch 6: 6 records to sensor_batch_0006_1756180464.json
# Written batch 6: 6 records to sensor_batch_0006_1756180464.json
# Written batch 7: 6 records to sensor_batch_0007_1756180469.json
# Written batch 7: 6 records to sensor_batch_0007_1756180469.json
# Written batch 8: 6 records to sensor_batch_0008_1756180474.json
# Written batch 8: 6 records to sensor_batch_0008_1756180474.json
# Written batch 9: 6 records to sensor_batch_0009_1756180479.json
# Written batch 9: 6 records to sensor_batch_0009_1756180479.json
# Written batch 10: 6 records to sensor_batch_0010_1756180484.json
# Written batch 10: 6 records to sensor_batch_0010_1756180484.json
# Written batch 11: 6 records to sensor_batch_0011_1756180489.json
# Written batch 11: 6 records to sensor_batch_0011_1756180489.json
# Written batch 12: 6 records to sensor_batch_0012_1756180494.json
# Written batch 12: 6 records to sensor_batch_0012_1756180494.json
# Written batch 13: 6 records to sensor_batch_0013_1756180499.json
# Written batch 13: 6 records to sensor_batch_0013_1756180499.json
# Written batch 14: 6 records to sensor_batch_0014_1756180504.json
# Written batch 14: 6 records to sensor_batch_0014_1756180504.json
# Written batch 15: 6 records to sensor_batch_0015_1756180509.json
# Written batch 15: 6 records to sensor_batch_0015_1756180509.json
# Written batch 16: 6 records to sensor_batch_0016_1756180514.json
# Written batch 16: 6 records to sensor_batch_0016_1756180514.json
# Written batch 17: 6 records to sensor_batch_0017_1756180519.json
# Written batch 17: 6 records to sensor_batch_0017_1756180519.json
# Written batch 18: 6 records to sensor_batch_0018_1756180524.json
# Written batch 18: 6 records to sensor_batch_0018_1756180524.json
# Written batch 19: 6 records to sensor_batch_0019_1756180529.json
# Written batch 19: 6 records to sensor_batch_0019_1756180529.json
# Written batch 20: 6 records to sensor_batch_0020_1756180534.json
# Written batch 20: 6 records to sensor_batch_0020_1756180534.json
# Written batch 21: 6 records to sensor_batch_0021_1756180539.json
# Written batch 21: 6 records to sensor_batch_0021_1756180539.json
# Written batch 22: 6 records to sensor_batch_0022_1756180544.json
# Written batch 22: 6 records to sensor_batch_0022_1756180544.json
# Written batch 23: 6 records to sensor_batch_0023_1756180549.json
# Written batch 23: 6 records to sensor_batch_0023_1756180549.json
# Written batch 24: 6 records to sensor_batch_0024_1756180554.json
# Written batch 24: 6 records to sensor_batch_0024_1756180554.json
# Written batch 25: 6 records to sensor_batch_0025_1756180559.json
# Written batch 25: 6 records to sensor_batch_0025_1756180559.json
# Written batch 26: 6 records to sensor_batch_0026_1756180564.json
# Written batch 26: 6 records to sensor_batch_0026_1756180564.json
# Written batch 27: 6 records to sensor_batch_0027_1756180569.json
# Written batch 27: 6 records to sensor_batch_0027_1756180569.json
# Written batch 28: 6 records to sensor_batch_0028_1756180574.json
# Written batch 28: 6 records to sensor_batch_0028_1756180574.json
# Written batch 29: 6 records to sensor_batch_0029_1756180579.json
# Written batch 29: 6 records to sensor_batch_0029_1756180579.json
# Written batch 30: 6 records to sensor_batch_0030_1756180584.json
# Written batch 30: 6 records to sensor_batch_0030_1756180584.json
# Written batch 31: 6 records to sensor_batch_0031_1756180589.json
# Written batch 31: 6 records to sensor_batch_0031_1756180589.json
# Written batch 32: 6 records to sensor_batch_0032_1756180594.json
# Written batch 32: 6 records to sensor_batch_0032_1756180594.json
# Written batch 33: 6 records to sensor_batch_0033_1756180599.json
# Written batch 33: 6 records to sensor_batch_0033_1756180599.json
# Written batch 34: 6 records to sensor_batch_0034_1756180604.json
# Written batch 34: 6 records to sensor_batch_0034_1756180604.json
# Written batch 35: 6 records to sensor_batch_0035_1756180609.json
# Written batch 35: 6 records to sensor_batch_0035_1756180609.json
# Written batch 36: 6 records to sensor_batch_0036_1756180614.json
# Written batch 36: 6 records to sensor_batch_0036_1756180614.json
# Written batch 37: 6 records to sensor_batch_0037_1756180619.json
# Written batch 37: 6 records to sensor_batch_0037_1756180619.json
# Written batch 38: 6 records to sensor_batch_0038_1756180624.json
# Written batch 38: 6 records to sensor_batch_0038_1756180624.json
# Written batch 39: 6 records to sensor_batch_0039_1756180629.json
# Written batch 39: 6 records to sensor_batch_0039_1756180629.json
# Written batch 40: 6 records to sensor_batch_0040_1756180634.json
# Written batch 40: 6 records to sensor_batch_0040_1756180634.json
# Written batch 41: 6 records to sensor_batch_0041_1756180639.json
# Written batch 41: 6 records to sensor_batch_0041_1756180639.json
# Written batch 42: 6 records to sensor_batch_0042_1756180644.json
# Written batch 42: 6 records to sensor_batch_0042_1756180644.json
# Written batch 43: 6 records to sensor_batch_0043_1756180649.json
# Written batch 43: 6 records to sensor_batch_0043_1756180649.json
# Written batch 44: 6 records to sensor_batch_0044_1756180654.json
# Written batch 44: 6 records to sensor_batch_0044_1756180654.json
# Written batch 45: 6 records to sensor_batch_0045_1756180659.json
# Written batch 45: 6 records to sensor_batch_0045_1756180659.json
# Written batch 46: 6 records to sensor_batch_0046_1756180664.json
# Written batch 46: 6 records to sensor_batch_0046_1756180664.json
# Written batch 47: 6 records to sensor_batch_0047_1756180669.json
# Written batch 47: 6 records to sensor_batch_0047_1756180669.json
# Written batch 48: 6 records to sensor_batch_0048_1756180674.json
# Written batch 48: 6 records to sensor_batch_0048_1756180674.json
# Written batch 49: 6 records to sensor_batch_0049_1756180679.json
# Written batch 49: 6 records to sensor_batch_0049_1756180679.json
# Written batch 50: 6 records to sensor_batch_0050_1756180684.json
# Written batch 50: 6 records to sensor_batch_0050_1756180684.json
# Written batch 51: 6 records to sensor_batch_0051_1756180689.json
# Written batch 51: 6 records to sensor_batch_0051_1756180689.json
# Written batch 52: 6 records to sensor_batch_0052_1756180694.json
# Written batch 52: 6 records to sensor_batch_0052_1756180694.json
# Written batch 53: 6 records to sensor_batch_0053_1756180699.json
# Written batch 53: 6 records to sensor_batch_0053_1756180699.json
# Written batch 54: 6 records to sensor_batch_0054_1756180704.json
# Written batch 54: 6 records to sensor_batch_0054_1756180704.json
# Written batch 55: 6 records to sensor_batch_0055_1756180709.json
# Written batch 55: 6 records to sensor_batch_0055_1756180709.json
# Written batch 56: 6 records to sensor_batch_0056_1756180714.json
# Written batch 56: 6 records to sensor_batch_0056_1756180714.json
# Written batch 57: 6 records to sensor_batch_0057_1756180719.json
# Written batch 57: 6 records to sensor_batch_0057_1756180719.json
# Written batch 58: 6 records to sensor_batch_0058_1756180724.json
# Written batch 58: 6 records to sensor_batch_0058_1756180724.json
# Written batch 59: 6 records to sensor_batch_0059_1756180729.json
# Written batch 59: 6 records to sensor_batch_0059_1756180729.json
# Written batch 60: 6 records to sensor_batch_0060_1756180734.json
# Written batch 60: 6 records to sensor_batch_0060_1756180734.json
# Written batch 61: 6 records to sensor_batch_0061_1756180739.json
# Written batch 61: 6 records to sensor_batch_0061_1756180739.json
# Written batch 62: 6 records to sensor_batch_0062_1756180744.json
# Written batch 62: 6 records to sensor_batch_0062_1756180744.json
# Written batch 63: 6 records to sensor_batch_0063_1756180749.json
# Written batch 63: 6 records to sensor_batch_0063_1756180749.json
# Written batch 64: 6 records to sensor_batch_0064_1756180754.json
# Written batch 64: 6 records to sensor_batch_0064_1756180754.json
# Written batch 65: 6 records to sensor_batch_0065_1756180759.json
# Written batch 65: 6 records to sensor_batch_0065_1756180759.json
# Written batch 66: 6 records to sensor_batch_0066_1756180764.json
# Written batch 66: 6 records to sensor_batch_0066_1756180764.json
# Written batch 67: 6 records to sensor_batch_0067_1756180769.json
# Written batch 67: 6 records to sensor_batch_0067_1756180769.json
# Written batch 68: 6 records to sensor_batch_0068_1756180774.json
# Written batch 68: 6 records to sensor_batch_0068_1756180774.json
# Written batch 69: 6 records to sensor_batch_0069_1756180779.json
# Written batch 69: 6 records to sensor_batch_0069_1756180779.json
# Written batch 70: 6 records to sensor_batch_0070_1756180784.json
# Written batch 70: 6 records to sensor_batch_0070_1756180784.json
# Written batch 71: 6 records to sensor_batch_0071_1756180789.json
# Written batch 71: 6 records to sensor_batch_0071_1756180789.json
# Written batch 72: 6 records to sensor_batch_0072_1756180794.json
# Written batch 72: 6 records to sensor_batch_0072_1756180794.json
# Written batch 73: 6 records to sensor_batch_0073_1756180799.json
# Written batch 73: 6 records to sensor_batch_0073_1756180799.json
# Written batch 74: 6 records to sensor_batch_0074_1756180804.json
# Written batch 74: 6 records to sensor_batch_0074_1756180804.json
# Written batch 75: 6 records to sensor_batch_0075_1756180809.json
# Written batch 75: 6 records to sensor_batch_0075_1756180809.json
# Written batch 76: 6 records to sensor_batch_0076_1756180814.json
# Written batch 76: 6 records to sensor_batch_0076_1756180814.json
# Written batch 77: 6 records to sensor_batch_0077_1756180819.json
# Written batch 77: 6 records to sensor_batch_0077_1756180819.json
# Written batch 78: 6 records to sensor_batch_0078_1756180824.json
# Written batch 78: 6 records to sensor_batch_0078_1756180824.json
# Written batch 79: 6 records to sensor_batch_0079_1756180829.json
# Written batch 79: 6 records to sensor_batch_0079_1756180829.json
# Written batch 80: 6 records to sensor_batch_0080_1756180834.json
# Written batch 80: 6 records to sensor_batch_0080_1756180834.json
# Written batch 81: 6 records to sensor_batch_0081_1756180839.json
# Written batch 81: 6 records to sensor_batch_0081_1756180839.json
# Written batch 82: 6 records to sensor_batch_0082_1756180844.json
# Written batch 82: 6 records to sensor_batch_0082_1756180844.json
# Written batch 83: 6 records to sensor_batch_0083_1756180849.json
# Written batch 83: 6 records to sensor_batch_0083_1756180849.json
# Written batch 84: 6 records to sensor_batch_0084_1756180854.json
# Written batch 84: 6 records to sensor_batch_0084_1756180854.json
# Written batch 85: 6 records to sensor_batch_0085_1756180859.json
# Written batch 85: 6 records to sensor_batch_0085_1756180859.json
# Written batch 86: 6 records to sensor_batch_0086_1756180864.json
# Written batch 86: 6 records to sensor_batch_0086_1756180864.json
# Written batch 87: 6 records to sensor_batch_0087_1756180869.json
# Written batch 87: 6 records to sensor_batch_0087_1756180869.json
# Written batch 88: 6 records to sensor_batch_0088_1756180874.json
# Written batch 88: 6 records to sensor_batch_0088_1756180874.json
# Written batch 89: 6 records to sensor_batch_0089_1756180879.json
# Written batch 89: 6 records to sensor_batch_0089_1756180879.json
# Written batch 90: 6 records to sensor_batch_0090_1756180884.json
# Written batch 90: 6 records to sensor_batch_0090_1756180884.json
# Written batch 91: 6 records to sensor_batch_0091_1756180889.json
# Written batch 91: 6 records to sensor_batch_0091_1756180889.json
# Written batch 92: 6 records to sensor_batch_0092_1756180894.json
# Written batch 92: 6 records to sensor_batch_0092_1756180894.json
# Written batch 93: 6 records to sensor_batch_0093_1756180899.json
# Written batch 93: 6 records to sensor_batch_0093_1756180899.json
# Written batch 94: 6 records to sensor_batch_0094_1756180904.json
# Written batch 94: 6 records to sensor_batch_0094_1756180904.json
# Written batch 95: 6 records to sensor_batch_0095_1756180909.json
# Written batch 95: 6 records to sensor_batch_0095_1756180909.json
# Written batch 96: 6 records to sensor_batch_0096_1756180914.json
# Written batch 96: 6 records to sensor_batch_0096_1756180914.json
# Written batch 97: 6 records to sensor_batch_0097_1756180919.json
# Written batch 97: 6 records to sensor_batch_0097_1756180919.json
# Written batch 98: 6 records to sensor_batch_0098_1756180924.json
# Written batch 98: 6 records to sensor_batch_0098_1756180924.json
# Written batch 99: 6 records to sensor_batch_0099_1756180929.json
# Written batch 99: 6 records to sensor_batch_0099_1756180929.json
# Written batch 100: 6 records to sensor_batch_0100_1756180934.json
# Written batch 100: 6 records to sensor_batch_0100_1756180934.json
# Written batch 101: 6 records to sensor_batch_0101_1756180939.json
# Written batch 101: 6 records to sensor_batch_0101_1756180939.json
# Written batch 102: 6 records to sensor_batch_0102_1756180944.json
# Written batch 102: 6 records to sensor_batch_0102_1756180944.json
# Written batch 103: 6 records to sensor_batch_0103_1756180949.json
# Written batch 103: 6 records to sensor_batch_0103_1756180949.json
# Written batch 104: 6 records to sensor_batch_0104_1756180954.json
# Written batch 104: 6 records to sensor_batch_0104_1756180954.json
# Written batch 105: 6 records to sensor_batch_0105_1756180959.json
# Written batch 105: 6 records to sensor_batch_0105_1756180959.json
# Written batch 106: 6 records to sensor_batch_0106_1756180964.json
# Written batch 106: 6 records to sensor_batch_0106_1756180964.json
# Written batch 107: 6 records to sensor_batch_0107_1756180969.json
# Written batch 107: 6 records to sensor_batch_0107_1756180969.json
# Written batch 108: 6 records to sensor_batch_0108_1756180974.json
# Written batch 108: 6 records to sensor_batch_0108_1756180974.json
# Written batch 109: 6 records to sensor_batch_0109_1756180979.json
# Written batch 109: 6 records to sensor_batch_0109_1756180979.json
# Written batch 110: 6 records to sensor_batch_0110_1756180984.json
# Written batch 110: 6 records to sensor_batch_0110_1756180984.json
# Written batch 111: 6 records to sensor_batch_0111_1756180989.json
# Written batch 111: 6 records to sensor_batch_0111_1756180989.json
# Written batch 112: 6 records to sensor_batch_0112_1756180994.json
# Written batch 112: 6 records to sensor_batch_0112_1756180994.json
# Written batch 113: 6 records to sensor_batch_0113_1756180999.json
# Written batch 113: 6 records to sensor_batch_0113_1756180999.json
# Written batch 114: 6 records to sensor_batch_0114_1756181004.json
# Written batch 114: 6 records to sensor_batch_0114_1756181004.json
# Written batch 115: 6 records to sensor_batch_0115_1756181009.json
# Written batch 115: 6 records to sensor_batch_0115_1756181009.json
# Written batch 116: 6 records to sensor_batch_0116_1756181014.json
# Written batch 116: 6 records to sensor_batch_0116_1756181014.json
# Written batch 117: 6 records to sensor_batch_0117_1756181019.json
# Written batch 117: 6 records to sensor_batch_0117_1756181019.json
# Written batch 118: 6 records to sensor_batch_0118_1756181024.json
# Written batch 118: 6 records to sensor_batch_0118_1756181024.json
# Written batch 119: 6 records to sensor_batch_0119_1756181029.json
# Written batch 119: 6 records to sensor_batch_0119_1756181029.json
# Written batch 120: 6 records to sensor_batch_0120_1756181034.json
# Written batch 120: 6 records to sensor_batch_0120_1756181034.json
# Written batch 121: 6 records to sensor_batch_0121_1756181039.json
# Written batch 121: 6 records to sensor_batch_0121_1756181039.json
# Written batch 122: 6 records to sensor_batch_0122_1756181044.json
# Written batch 122: 6 records to sensor_batch_0122_1756181044.json
# Written batch 123: 6 records to sensor_batch_0123_1756181049.json
# Written batch 123: 6 records to sensor_batch_0123_1756181049.json
# Written batch 124: 6 records to sensor_batch_0124_1756181054.json
# Written batch 124: 6 records to sensor_batch_0124_1756181054.json
# Written batch 125: 6 records to sensor_batch_0125_1756181059.json
# Written batch 125: 6 records to sensor_batch_0125_1756181059.json
# Written batch 126: 6 records to sensor_batch_0126_1756181064.json
# Written batch 126: 6 records to sensor_batch_0126_1756181064.json
# Written batch 127: 6 records to sensor_batch_0127_1756181069.json
# Written batch 127: 6 records to sensor_batch_0127_1756181069.json
# Written batch 128: 6 records to sensor_batch_0128_1756181074.json
# Written batch 128: 6 records to sensor_batch_0128_1756181074.json
# Written batch 129: 6 records to sensor_batch_0129_1756181079.json
# Written batch 129: 6 records to sensor_batch_0129_1756181079.json
# Written batch 130: 6 records to sensor_batch_0130_1756181084.json
# Written batch 130: 6 records to sensor_batch_0130_1756181084.json
# Written batch 131: 6 records to sensor_batch_0131_1756181089.json
# Written batch 131: 6 records to sensor_batch_0131_1756181089.json
# Written batch 132: 6 records to sensor_batch_0132_1756181094.json
# Written batch 132: 6 records to sensor_batch_0132_1756181094.json
# Written batch 133: 6 records to sensor_batch_0133_1756181099.json
# Written batch 133: 6 records to sensor_batch_0133_1756181099.json
# Written batch 134: 6 records to sensor_batch_0134_1756181104.json
# Written batch 134: 6 records to sensor_batch_0134_1756181104.json
# Written batch 135: 6 records to sensor_batch_0135_1756181109.json
# Written batch 135: 6 records to sensor_batch_0135_1756181109.json
# Written batch 136: 6 records to sensor_batch_0136_1756181114.json
# Written batch 136: 6 records to sensor_batch_0136_1756181114.json
# Written batch 137: 6 records to sensor_batch_0137_1756181119.json
# Written batch 137: 6 records to sensor_batch_0137_1756181119.json
# Written batch 138: 6 records to sensor_batch_0138_1756181124.json
# Written batch 138: 6 records to sensor_batch_0138_1756181124.json
# Written batch 139: 6 records to sensor_batch_0139_1756181129.json
# Written batch 139: 6 records to sensor_batch_0139_1756181129.json
# Written batch 140: 6 records to sensor_batch_0140_1756181134.json
# Written batch 140: 6 records to sensor_batch_0140_1756181134.json
# Written batch 141: 6 records to sensor_batch_0141_1756181139.json
# Written batch 141: 6 records to sensor_batch_0141_1756181139.json
# Written batch 142: 6 records to sensor_batch_0142_1756181144.json
# Written batch 142: 6 records to sensor_batch_0142_1756181144.json
# Written batch 143: 6 records to sensor_batch_0143_1756181149.json
# Written batch 143: 6 records to sensor_batch_0143_1756181149.json
# Written batch 144: 6 records to sensor_batch_0144_1756181154.json
# Written batch 144: 6 records to sensor_batch_0144_1756181154.json
# Written batch 145: 6 records to sensor_batch_0145_1756181159.json
# Written batch 145: 6 records to sensor_batch_0145_1756181159.json
# Written batch 146: 6 records to sensor_batch_0146_1756181164.json
# Written batch 146: 6 records to sensor_batch_0146_1756181164.json
# Written batch 147: 6 records to sensor_batch_0147_1756181169.json
# Written batch 147: 6 records to sensor_batch_0147_1756181169.json
# Written batch 148: 6 records to sensor_batch_0148_1756181174.json
# Written batch 148: 6 records to sensor_batch_0148_1756181174.json
# Written batch 149: 6 records to sensor_batch_0149_1756181179.json
# Written batch 149: 6 records to sensor_batch_0149_1756181179.json
# Written batch 150: 6 records to sensor_batch_0150_1756181184.json
# Written batch 150: 6 records to sensor_batch_0150_1756181184.json
# Written batch 151: 6 records to sensor_batch_0151_1756181189.json
# Written batch 151: 6 records to sensor_batch_0151_1756181189.json
# Written batch 152: 6 records to sensor_batch_0152_1756181194.json
# Written batch 152: 6 records to sensor_batch_0152_1756181194.json
# Written batch 153: 6 records to sensor_batch_0153_1756181199.json
# Written batch 153: 6 records to sensor_batch_0153_1756181199.json
# Written batch 154: 6 records to sensor_batch_0154_1756181204.json
# Written batch 154: 6 records to sensor_batch_0154_1756181204.json
# Written batch 155: 6 records to sensor_batch_0155_1756181209.json
# Written batch 155: 6 records to sensor_batch_0155_1756181209.json
# Written batch 156: 6 records to sensor_batch_0156_1756181214.json
# Written batch 156: 6 records to sensor_batch_0156_1756181214.json
# Written batch 157: 6 records to sensor_batch_0157_1756181219.json
# Written batch 157: 6 records to sensor_batch_0157_1756181219.json
# Written batch 158: 6 records to sensor_batch_0158_1756181224.json
# Written batch 158: 6 records to sensor_batch_0158_1756181224.json
# Written batch 159: 6 records to sensor_batch_0159_1756181229.json
# Written batch 159: 6 records to sensor_batch_0159_1756181229.json
# Written batch 160: 6 records to sensor_batch_0160_1756181234.json
# Written batch 160: 6 records to sensor_batch_0160_1756181234.json
# Written batch 161: 6 records to sensor_batch_0161_1756181239.json
# Written batch 161: 6 records to sensor_batch_0161_1756181239.json
# Written batch 162: 6 records to sensor_batch_0162_1756181244.json
# Written batch 162: 6 records to sensor_batch_0162_1756181244.json
# Written batch 163: 6 records to sensor_batch_0163_1756181249.json
# Written batch 163: 6 records to sensor_batch_0163_1756181249.json
# Written batch 164: 6 records to sensor_batch_0164_1756181254.json
# Written batch 164: 6 records to sensor_batch_0164_1756181254.json
# Written batch 165: 6 records to sensor_batch_0165_1756181259.json
# Written batch 165: 6 records to sensor_batch_0165_1756181259.json
# Written batch 166: 6 records to sensor_batch_0166_1756181264.json
# Written batch 166: 6 records to sensor_batch_0166_1756181264.json
# Written batch 167: 6 records to sensor_batch_0167_1756181269.json
# Written batch 167: 6 records to sensor_batch_0167_1756181269.json
# Written batch 168: 6 records to sensor_batch_0168_1756181274.json
# Written batch 168: 6 records to sensor_batch_0168_1756181274.json
# Written batch 169: 6 records to sensor_batch_0169_1756181279.json
# Written batch 169: 6 records to sensor_batch_0169_1756181279.json
# Written batch 170: 6 records to sensor_batch_0170_1756181284.json
# Written batch 170: 6 records to sensor_batch_0170_1756181284.json
# Written batch 171: 6 records to sensor_batch_0171_1756181289.json
# Written batch 171: 6 records to sensor_batch_0171_1756181289.json
# Written batch 172: 6 records to sensor_batch_0172_1756181294.json
# Written batch 172: 6 records to sensor_batch_0172_1756181294.json
# Written batch 173: 6 records to sensor_batch_0173_1756181299.json
# Written batch 173: 6 records to sensor_batch_0173_1756181299.json
# Written batch 174: 6 records to sensor_batch_0174_1756181304.json
# Written batch 174: 6 records to sensor_batch_0174_1756181304.json
# Written batch 175: 6 records to sensor_batch_0175_1756181309.json
# Written batch 175: 6 records to sensor_batch_0175_1756181309.json
# Written batch 176: 6 records to sensor_batch_0176_1756181314.json
# Written batch 176: 6 records to sensor_batch_0176_1756181314.json
# Written batch 177: 6 records to sensor_batch_0177_1756181319.json
# Written batch 177: 6 records to sensor_batch_0177_1756181319.json
# Written batch 178: 6 records to sensor_batch_0178_1756181324.json
# Written batch 178: 6 records to sensor_batch_0178_1756181324.json
# Written batch 179: 6 records to sensor_batch_0179_1756181329.json
# Written batch 179: 6 records to sensor_batch_0179_1756181329.json
# Written batch 180: 6 records to sensor_batch_0180_1756181334.json
# Written batch 180: 6 records to sensor_batch_0180_1756181334.json
# Written batch 181: 6 records to sensor_batch_0181_1756181339.json
# Written batch 181: 6 records to sensor_batch_0181_1756181339.json
# Written batch 182: 6 records to sensor_batch_0182_1756181344.json
# Written batch 182: 6 records to sensor_batch_0182_1756181344.json
# Written batch 183: 6 records to sensor_batch_0183_1756181349.json
# Written batch 183: 6 records to sensor_batch_0183_1756181349.json
# Written batch 184: 6 records to sensor_batch_0184_1756181354.json
# Written batch 184: 6 records to sensor_batch_0184_1756181354.json
# Written batch 185: 6 records to sensor_batch_0185_1756181359.json
# Written batch 185: 6 records to sensor_batch_0185_1756181359.json
# Written batch 186: 6 records to sensor_batch_0186_1756181364.json
# Written batch 186: 6 records to sensor_batch_0186_1756181364.json
# Written batch 187: 6 records to sensor_batch_0187_1756181369.json
# Written batch 187: 6 records to sensor_batch_0187_1756181369.json
# Written batch 188: 6 records to sensor_batch_0188_1756181374.json
# Written batch 188: 6 records to sensor_batch_0188_1756181374.json
# Written batch 189: 6 records to sensor_batch_0189_1756181379.json
# Written batch 189: 6 records to sensor_batch_0189_1756181379.json
# Written batch 190: 6 records to sensor_batch_0190_1756181385.json
# Written batch 190: 6 records to sensor_batch_0190_1756181385.json
# Written batch 191: 6 records to sensor_batch_0191_1756181390.json
# Written batch 191: 6 records to sensor_batch_0191_1756181390.json
# Written batch 192: 6 records to sensor_batch_0192_1756181395.json
# Written batch 192: 6 records to sensor_batch_0192_1756181395.json
# Written batch 193: 6 records to sensor_batch_0193_1756181400.json
# Written batch 193: 6 records to sensor_batch_0193_1756181400.json
# Written batch 194: 6 records to sensor_batch_0194_1756181405.json
# Written batch 194: 6 records to sensor_batch_0194_1756181405.json
# Written batch 195: 6 records to sensor_batch_0195_1756181410.json
# Written batch 195: 6 records to sensor_batch_0195_1756181410.json
# Written batch 196: 6 records to sensor_batch_0196_1756181415.json
# Written batch 196: 6 records to sensor_batch_0196_1756181415.json
# Written batch 197: 6 records to sensor_batch_0197_1756181420.json
# Written batch 197: 6 records to sensor_batch_0197_1756181420.json
# Written batch 198: 6 records to sensor_batch_0198_1756181425.json
# Written batch 198: 6 records to sensor_batch_0198_1756181425.json
# Written batch 199: 6 records to sensor_batch_0199_1756181430.json
# Written batch 199: 6 records to sensor_batch_0199_1756181430.json
# Written batch 200: 6 records to sensor_batch_0200_1756181435.json
# Written batch 200: 6 records to sensor_batch_0200_1756181435.json
# Written batch 201: 6 records to sensor_batch_0201_1756181440.json
# Written batch 201: 6 records to sensor_batch_0201_1756181440.json
# Written batch 202: 6 records to sensor_batch_0202_1756181445.json
# Written batch 202: 6 records to sensor_batch_0202_1756181445.json
# Written batch 203: 6 records to sensor_batch_0203_1756181450.json
# Written batch 203: 6 records to sensor_batch_0203_1756181450.json
# Written batch 204: 6 records to sensor_batch_0204_1756181455.json
# Written batch 204: 6 records to sensor_batch_0204_1756181455.json
# Written batch 205: 6 records to sensor_batch_0205_1756181460.json
# Written batch 205: 6 records to sensor_batch_0205_1756181460.json
# Written batch 206: 6 records to sensor_batch_0206_1756181465.json
# Written batch 206: 6 records to sensor_batch_0206_1756181465.json
# Written batch 207: 6 records to sensor_batch_0207_1756181470.json
# Written batch 207: 6 records to sensor_batch_0207_1756181470.json
# Written batch 208: 6 records to sensor_batch_0208_1756181475.json
# Written batch 208: 6 records to sensor_batch_0208_1756181475.json
# Written batch 209: 6 records to sensor_batch_0209_1756181480.json
# Written batch 209: 6 records to sensor_batch_0209_1756181480.json
# Written batch 210: 6 records to sensor_batch_0210_1756181485.json
# Written batch 210: 6 records to sensor_batch_0210_1756181485.json
# Written batch 211: 6 records to sensor_batch_0211_1756181490.json
# Written batch 211: 6 records to sensor_batch_0211_1756181490.json
# Written batch 212: 6 records to sensor_batch_0212_1756181495.json
# Written batch 212: 6 records to sensor_batch_0212_1756181495.json
# Written batch 213: 6 records to sensor_batch_0213_1756181500.json
# Written batch 213: 6 records to sensor_batch_0213_1756181500.json
# Written batch 214: 6 records to sensor_batch_0214_1756181505.json
# Written batch 214: 6 records to sensor_batch_0214_1756181505.json
# Written batch 215: 6 records to sensor_batch_0215_1756181510.json
# Written batch 215: 6 records to sensor_batch_0215_1756181510.json
# Written batch 216: 6 records to sensor_batch_0216_1756181515.json
# Written batch 216: 6 records to sensor_batch_0216_1756181515.json
# Written batch 217: 6 records to sensor_batch_0217_1756181520.json
# Written batch 217: 6 records to sensor_batch_0217_1756181520.json
# Written batch 218: 6 records to sensor_batch_0218_1756181525.json
# Written batch 218: 6 records to sensor_batch_0218_1756181525.json
# Written batch 219: 6 records to sensor_batch_0219_1756181530.json
# Written batch 219: 6 records to sensor_batch_0219_1756181530.json
# Written batch 220: 6 records to sensor_batch_0220_1756181535.json
# Written batch 220: 6 records to sensor_batch_0220_1756181535.json
# Written batch 221: 6 records to sensor_batch_0221_1756181540.json
# Written batch 221: 6 records to sensor_batch_0221_1756181540.json
# Written batch 222: 6 records to sensor_batch_0222_1756181545.json
# Written batch 222: 6 records to sensor_batch_0222_1756181545.json
# Written batch 223: 6 records to sensor_batch_0223_1756181550.json
# Written batch 223: 6 records to sensor_batch_0223_1756181550.json
# Written batch 224: 6 records to sensor_batch_0224_1756181555.json
# Written batch 224: 6 records to sensor_batch_0224_1756181555.json
# Written batch 225: 6 records to sensor_batch_0225_1756181560.json
# Written batch 225: 6 records to sensor_batch_0225_1756181560.json
# Written batch 226: 6 records to sensor_batch_0226_1756181565.json
# Written batch 226: 6 records to sensor_batch_0226_1756181565.json
# Written batch 227: 6 records to sensor_batch_0227_1756181570.json
# Written batch 227: 6 records to sensor_batch_0227_1756181570.json
# Written batch 228: 6 records to sensor_batch_0228_1756181575.json
# Written batch 228: 6 records to sensor_batch_0228_1756181575.json
# Written batch 229: 6 records to sensor_batch_0229_1756181580.json
# Written batch 229: 6 records to sensor_batch_0229_1756181580.json
# Written batch 230: 6 records to sensor_batch_0230_1756181585.json
# Written batch 230: 6 records to sensor_batch_0230_1756181585.json
# Written batch 231: 6 records to sensor_batch_0231_1756181590.json
# Written batch 231: 6 records to sensor_batch_0231_1756181590.json
# Written batch 232: 6 records to sensor_batch_0232_1756181595.json
# Written batch 232: 6 records to sensor_batch_0232_1756181595.json
# Written batch 233: 6 records to sensor_batch_0233_1756181600.json
# Written batch 233: 6 records to sensor_batch_0233_1756181600.json
# Written batch 234: 6 records to sensor_batch_0234_1756181605.json
# Written batch 234: 6 records to sensor_batch_0234_1756181605.json
# Written batch 235: 6 records to sensor_batch_0235_1756181610.json
# Written batch 235: 6 records to sensor_batch_0235_1756181610.json
# Written batch 236: 6 records to sensor_batch_0236_1756181615.json
# Written batch 236: 6 records to sensor_batch_0236_1756181615.json
# Written batch 237: 6 records to sensor_batch_0237_1756181620.json
# Written batch 237: 6 records to sensor_batch_0237_1756181620.json
# Written batch 238: 6 records to sensor_batch_0238_1756181625.json
# Written batch 238: 6 records to sensor_batch_0238_1756181625.json
# Written batch 239: 6 records to sensor_batch_0239_1756181630.json
# Written batch 239: 6 records to sensor_batch_0239_1756181630.json
# Written batch 240: 6 records to sensor_batch_0240_1756181635.json
# Written batch 240: 6 records to sensor_batch_0240_1756181635.json
# Written batch 241: 6 records to sensor_batch_0241_1756181640.json
# Written batch 241: 6 records to sensor_batch_0241_1756181640.json
# Written batch 242: 6 records to sensor_batch_0242_1756181645.json
# Written batch 242: 6 records to sensor_batch_0242_1756181645.json
# Written batch 243: 6 records to sensor_batch_0243_1756181650.json
# Written batch 243: 6 records to sensor_batch_0243_1756181650.json
# Written batch 244: 6 records to sensor_batch_0244_1756181655.json
# Written batch 244: 6 records to sensor_batch_0244_1756181655.json
# Written batch 245: 6 records to sensor_batch_0245_1756181660.json
# Written batch 245: 6 records to sensor_batch_0245_1756181660.json
# Written batch 246: 6 records to sensor_batch_0246_1756181665.json
# Written batch 246: 6 records to sensor_batch_0246_1756181665.json
# Written batch 247: 6 records to sensor_batch_0247_1756181670.json
# Written batch 247: 6 records to sensor_batch_0247_1756181670.json
# Written batch 248: 6 records to sensor_batch_0248_1756181675.json
# Written batch 248: 6 records to sensor_batch_0248_1756181675.json
# Written batch 249: 6 records to sensor_batch_0249_1756181680.json
# Written batch 249: 6 records to sensor_batch_0249_1756181680.json
# Written batch 250: 6 records to sensor_batch_0250_1756181685.json
# Written batch 250: 6 records to sensor_batch_0250_1756181685.json
# Written batch 251: 6 records to sensor_batch_0251_1756181690.json
# Written batch 251: 6 records to sensor_batch_0251_1756181690.json
# Written batch 252: 6 records to sensor_batch_0252_1756181695.json
# Written batch 252: 6 records to sensor_batch_0252_1756181695.json
# Written batch 253: 6 records to sensor_batch_0253_1756181700.json
# Written batch 253: 6 records to sensor_batch_0253_1756181700.json
# Written batch 254: 6 records to sensor_batch_0254_1756181705.json
# Written batch 254: 6 records to sensor_batch_0254_1756181705.json
# Written batch 255: 6 records to sensor_batch_0255_1756181710.json
# Written batch 255: 6 records to sensor_batch_0255_1756181710.json
# Written batch 256: 6 records to sensor_batch_0256_1756181715.json
# Written batch 256: 6 records to sensor_batch_0256_1756181715.json
# Written batch 257: 6 records to sensor_batch_0257_1756181720.json
# Written batch 257: 6 records to sensor_batch_0257_1756181720.json
# Written batch 258: 6 records to sensor_batch_0258_1756181725.json
# Written batch 258: 6 records to sensor_batch_0258_1756181725.json
# Written batch 259: 6 records to sensor_batch_0259_1756181730.json
# Written batch 259: 6 records to sensor_batch_0259_1756181730.json
# Written batch 260: 6 records to sensor_batch_0260_1756181735.json
# Written batch 260: 6 records to sensor_batch_0260_1756181735.json
# Written batch 261: 6 records to sensor_batch_0261_1756181740.json
# Written batch 261: 6 records to sensor_batch_0261_1756181740.json
# Written batch 262: 6 records to sensor_batch_0262_1756181745.json
# Written batch 262: 6 records to sensor_batch_0262_1756181745.json
# Written batch 263: 6 records to sensor_batch_0263_1756181750.json
# Written batch 263: 6 records to sensor_batch_0263_1756181750.json
# Written batch 264: 6 records to sensor_batch_0264_1756181755.json
# Written batch 264: 6 records to sensor_batch_0264_1756181755.json
# Written batch 265: 6 records to sensor_batch_0265_1756181760.json
# Written batch 265: 6 records to sensor_batch_0265_1756181760.json
# Written batch 266: 6 records to sensor_batch_0266_1756181765.json
# Written batch 266: 6 records to sensor_batch_0266_1756181765.json
# Written batch 267: 6 records to sensor_batch_0267_1756181770.json
# Written batch 267: 6 records to sensor_batch_0267_1756181770.json
# Written batch 268: 6 records to sensor_batch_0268_1756181775.json
# Written batch 268: 6 records to sensor_batch_0268_1756181775.json
# Written batch 269: 6 records to sensor_batch_0269_1756181780.json
# Written batch 269: 6 records to sensor_batch_0269_1756181780.json
# Written batch 270: 6 records to sensor_batch_0270_1756181785.json
# Written batch 270: 6 records to sensor_batch_0270_1756181785.json
# Written batch 271: 6 records to sensor_batch_0271_1756181790.json
# Written batch 271: 6 records to sensor_batch_0271_1756181790.json
# Written batch 272: 6 records to sensor_batch_0272_1756181795.json
# Written batch 272: 6 records to sensor_batch_0272_1756181795.json
# Written batch 273: 6 records to sensor_batch_0273_1756181800.json
# Written batch 273: 6 records to sensor_batch_0273_1756181800.json
# Written batch 274: 6 records to sensor_batch_0274_1756181805.json
# Written batch 274: 6 records to sensor_batch_0274_1756181805.json
# Written batch 275: 6 records to sensor_batch_0275_1756181810.json
# Written batch 275: 6 records to sensor_batch_0275_1756181810.json
# Written batch 276: 6 records to sensor_batch_0276_1756181815.json
# Written batch 276: 6 records to sensor_batch_0276_1756181815.json
# Written batch 277: 6 records to sensor_batch_0277_1756181820.json
# Written batch 277: 6 records to sensor_batch_0277_1756181820.json
# Written batch 278: 6 records to sensor_batch_0278_1756181825.json
# Written batch 278: 6 records to sensor_batch_0278_1756181825.json
# Written batch 279: 6 records to sensor_batch_0279_1756181830.json
# Written batch 279: 6 records to sensor_batch_0279_1756181830.json
# Written batch 280: 6 records to sensor_batch_0280_1756181835.json
# Written batch 280: 6 records to sensor_batch_0280_1756181835.json
# Written batch 281: 6 records to sensor_batch_0281_1756181840.json
# Written batch 281: 6 records to sensor_batch_0281_1756181840.json
# Written batch 282: 6 records to sensor_batch_0282_1756181845.json
# Written batch 282: 6 records to sensor_batch_0282_1756181845.json
# Written batch 283: 6 records to sensor_batch_0283_1756181850.json
# Written batch 283: 6 records to sensor_batch_0283_1756181850.json
# Written batch 284: 6 records to sensor_batch_0284_1756181855.json
# Written batch 284: 6 records to sensor_batch_0284_1756181855.json
# Written batch 285: 6 records to sensor_batch_0285_1756181860.json
# Written batch 285: 6 records to sensor_batch_0285_1756181860.json
# Written batch 286: 6 records to sensor_batch_0286_1756181865.json
# Written batch 286: 6 records to sensor_batch_0286_1756181865.json
# Written batch 287: 6 records to sensor_batch_0287_1756181870.json
# Written batch 287: 6 records to sensor_batch_0287_1756181870.json
# Written batch 288: 6 records to sensor_batch_0288_1756181875.json
# Written batch 288: 6 records to sensor_batch_0288_1756181875.json
# Written batch 289: 6 records to sensor_batch_0289_1756181880.json
# Written batch 289: 6 records to sensor_batch_0289_1756181880.json
# Written batch 290: 6 records to sensor_batch_0290_1756181885.json
# Written batch 290: 6 records to sensor_batch_0290_1756181885.json
# Written batch 291: 6 records to sensor_batch_0291_1756181890.json
# Written batch 291: 6 records to sensor_batch_0291_1756181890.json
# Written batch 292: 6 records to sensor_batch_0292_1756181895.json
# Written batch 292: 6 records to sensor_batch_0292_1756181895.json
# Written batch 293: 6 records to sensor_batch_0293_1756181900.json
# Written batch 293: 6 records to sensor_batch_0293_1756181900.json
# Written batch 294: 6 records to sensor_batch_0294_1756181905.json
# Written batch 294: 6 records to sensor_batch_0294_1756181905.json
# Written batch 295: 6 records to sensor_batch_0295_1756181910.json
# Written batch 295: 6 records to sensor_batch_0295_1756181910.json
# Written batch 296: 6 records to sensor_batch_0296_1756181915.json
# Written batch 296: 6 records to sensor_batch_0296_1756181915.json
# Written batch 297: 6 records to sensor_batch_0297_1756181920.json
# Written batch 297: 6 records to sensor_batch_0297_1756181920.json
# Written batch 298: 6 records to sensor_batch_0298_1756181925.json
# Written batch 298: 6 records to sensor_batch_0298_1756181925.json
# Written batch 299: 6 records to sensor_batch_0299_1756181930.json
# Written batch 299: 6 records to sensor_batch_0299_1756181930.json
# Written batch 300: 6 records to sensor_batch_0300_1756181935.json
# Written batch 300: 6 records to sensor_batch_0300_1756181935.json
# Written batch 301: 6 records to sensor_batch_0301_1756181940.json
# Written batch 301: 6 records to sensor_batch_0301_1756181940.json
# Written batch 302: 6 records to sensor_batch_0302_1756181945.json
# Written batch 302: 6 records to sensor_batch_0302_1756181945.json
# Written batch 303: 6 records to sensor_batch_0303_1756181950.json
# Written batch 303: 6 records to sensor_batch_0303_1756181950.json
# Written batch 304: 6 records to sensor_batch_0304_1756181955.json
# Written batch 304: 6 records to sensor_batch_0304_1756181955.json
# Written batch 305: 6 records to sensor_batch_0305_1756181960.json
# Written batch 305: 6 records to sensor_batch_0305_1756181960.json
# Written batch 306: 6 records to sensor_batch_0306_1756181965.json
# Written batch 306: 6 records to sensor_batch_0306_1756181965.json
# Written batch 307: 6 records to sensor_batch_0307_1756181970.json
# Written batch 307: 6 records to sensor_batch_0307_1756181970.json
# Written batch 308: 6 records to sensor_batch_0308_1756181975.json
# Written batch 308: 6 records to sensor_batch_0308_1756181975.json
# Written batch 309: 6 records to sensor_batch_0309_1756181980.json
# Written batch 309: 6 records to sensor_batch_0309_1756181980.json
# Written batch 310: 6 records to sensor_batch_0310_1756181985.json
# Written batch 310: 6 records to sensor_batch_0310_1756181985.json
# Written batch 311: 6 records to sensor_batch_0311_1756181990.json
# Written batch 311: 6 records to sensor_batch_0311_1756181990.json
# Written batch 312: 6 records to sensor_batch_0312_1756181995.json
# Written batch 312: 6 records to sensor_batch_0312_1756181995.json
# Written batch 313: 6 records to sensor_batch_0313_1756182000.json
# Written batch 313: 6 records to sensor_batch_0313_1756182000.json
# Written batch 314: 6 records to sensor_batch_0314_1756182005.json
# Written batch 314: 6 records to sensor_batch_0314_1756182005.json
# Written batch 315: 6 records to sensor_batch_0315_1756182010.json
# Written batch 315: 6 records to sensor_batch_0315_1756182010.json
# Written batch 316: 6 records to sensor_batch_0316_1756182015.json
# Written batch 316: 6 records to sensor_batch_0316_1756182015.json
# Written batch 317: 6 records to sensor_batch_0317_1756182020.json
# Written batch 317: 6 records to sensor_batch_0317_1756182020.json
# Written batch 318: 6 records to sensor_batch_0318_1756182025.json
# Written batch 318: 6 records to sensor_batch_0318_1756182025.json
# Written batch 319: 6 records to sensor_batch_0319_1756182030.json
# Written batch 319: 6 records to sensor_batch_0319_1756182030.json
# Written batch 320: 6 records to sensor_batch_0320_1756182035.json
# Written batch 320: 6 records to sensor_batch_0320_1756182035.json
# Written batch 321: 6 records to sensor_batch_0321_1756182040.json
# Written batch 321: 6 records to sensor_batch_0321_1756182040.json
# Written batch 322: 6 records to sensor_batch_0322_1756182045.json
# Written batch 322: 6 records to sensor_batch_0322_1756182045.json
# Written batch 323: 6 records to sensor_batch_0323_1756182050.json
# Written batch 323: 6 records to sensor_batch_0323_1756182050.json
# Written batch 324: 6 records to sensor_batch_0324_1756182055.json
# Written batch 324: 6 records to sensor_batch_0324_1756182055.json
# Written batch 325: 6 records to sensor_batch_0325_1756182060.json
# Written batch 325: 6 records to sensor_batch_0325_1756182060.json
# Written batch 326: 6 records to sensor_batch_0326_1756182065.json
# Written batch 326: 6 records to sensor_batch_0326_1756182065.json
# Written batch 327: 6 records to sensor_batch_0327_1756182070.json
# Written batch 327: 6 records to sensor_batch_0327_1756182070.json
# Written batch 328: 6 records to sensor_batch_0328_1756182075.json
# Written batch 328: 6 records to sensor_batch_0328_1756182075.json
# Written batch 329: 6 records to sensor_batch_0329_1756182080.json
# Written batch 329: 6 records to sensor_batch_0329_1756182080.json
# Written batch 330: 6 records to sensor_batch_0330_1756182085.json
# Written batch 330: 6 records to sensor_batch_0330_1756182085.json
# Written batch 331: 6 records to sensor_batch_0331_1756182090.json
# Written batch 331: 6 records to sensor_batch_0331_1756182090.json
# Written batch 332: 6 records to sensor_batch_0332_1756182095.json
# Written batch 332: 6 records to sensor_batch_0332_1756182095.json
# Written batch 333: 6 records to sensor_batch_0333_1756182100.json
# Written batch 333: 6 records to sensor_batch_0333_1756182100.json
# Written batch 334: 6 records to sensor_batch_0334_1756182105.json
# Written batch 334: 6 records to sensor_batch_0334_1756182105.json
# Written batch 335: 6 records to sensor_batch_0335_1756182110.json
# Written batch 335: 6 records to sensor_batch_0335_1756182110.json
# Written batch 336: 6 records to sensor_batch_0336_1756182115.json
# Written batch 336: 6 records to sensor_batch_0336_1756182115.json
# Written batch 337: 6 records to sensor_batch_0337_1756182120.json
# Written batch 337: 6 records to sensor_batch_0337_1756182120.json
# Written batch 338: 6 records to sensor_batch_0338_1756182125.json
# Written batch 338: 6 records to sensor_batch_0338_1756182125.json
# Written batch 339: 6 records to sensor_batch_0339_1756182130.json
# Written batch 339: 6 records to sensor_batch_0339_1756182130.json
# Written batch 340: 6 records to sensor_batch_0340_1756182135.json
# Written batch 340: 6 records to sensor_batch_0340_1756182135.json
# Written batch 341: 6 records to sensor_batch_0341_1756182140.json
# Written batch 341: 6 records to sensor_batch_0341_1756182140.json
# Written batch 342: 6 records to sensor_batch_0342_1756182145.json
# Written batch 342: 6 records to sensor_batch_0342_1756182145.json
# Written batch 343: 6 records to sensor_batch_0343_1756182150.json
# Written batch 343: 6 records to sensor_batch_0343_1756182150.json
# Written batch 344: 6 records to sensor_batch_0344_1756182155.json
# Written batch 344: 6 records to sensor_batch_0344_1756182155.json
# Written batch 345: 6 records to sensor_batch_0345_1756182160.json
# Written batch 345: 6 records to sensor_batch_0345_1756182160.json
# Written batch 346: 6 records to sensor_batch_0346_1756182165.json
# Written batch 346: 6 records to sensor_batch_0346_1756182165.json
# Written batch 347: 6 records to sensor_batch_0347_1756182170.json
# Written batch 347: 6 records to sensor_batch_0347_1756182170.json
# Written batch 348: 6 records to sensor_batch_0348_1756182175.json
# Written batch 348: 6 records to sensor_batch_0348_1756182175.json
# Written batch 349: 6 records to sensor_batch_0349_1756182180.json
# Written batch 349: 6 records to sensor_batch_0349_1756182180.json
# Written batch 350: 6 records to sensor_batch_0350_1756182185.json
# Written batch 350: 6 records to sensor_batch_0350_1756182185.json
# Written batch 351: 6 records to sensor_batch_0351_1756182190.json
# Written batch 351: 6 records to sensor_batch_0351_1756182190.json
# Written batch 352: 6 records to sensor_batch_0352_1756182195.json
# Written batch 352: 6 records to sensor_batch_0352_1756182195.json
# Written batch 353: 6 records to sensor_batch_0353_1756182200.json
# Written batch 353: 6 records to sensor_batch_0353_1756182200.json
# Written batch 354: 6 records to sensor_batch_0354_1756182205.json
# Written batch 354: 6 records to sensor_batch_0354_1756182205.json
# Written batch 355: 6 records to sensor_batch_0355_1756182210.json
# Written batch 355: 6 records to sensor_batch_0355_1756182210.json
# Written batch 356: 6 records to sensor_batch_0356_1756182215.json
# Written batch 356: 6 records to sensor_batch_0356_1756182215.json
# Written batch 357: 6 records to sensor_batch_0357_1756182220.json
# Written batch 357: 6 records to sensor_batch_0357_1756182220.json
# Written batch 358: 6 records to sensor_batch_0358_1756182225.json
# Written batch 358: 6 records to sensor_batch_0358_1756182225.json
# Written batch 359: 6 records to sensor_batch_0359_1756182230.json
# Written batch 359: 6 records to sensor_batch_0359_1756182230.json
# Written batch 360: 6 records to sensor_batch_0360_1756182235.json
# Written batch 360: 6 records to sensor_batch_0360_1756182235.json
# Written batch 361: 6 records to sensor_batch_0361_1756182240.json
# Written batch 361: 6 records to sensor_batch_0361_1756182240.json
# Written batch 362: 6 records to sensor_batch_0362_1756182245.json
# Written batch 362: 6 records to sensor_batch_0362_1756182245.json
# Written batch 363: 6 records to sensor_batch_0363_1756182250.json
# Written batch 363: 6 records to sensor_batch_0363_1756182250.json
# Written batch 364: 6 records to sensor_batch_0364_1756182255.json
# Written batch 364: 6 records to sensor_batch_0364_1756182255.json
# ...
# Written batch 378: 6 records to sensor_batch_0378_1756182325.json
# Written batch 378: 6 records to sensor_batch_0378_1756182325.json
# Written batch 379: 6 records to sensor_batch_0379_1756182330.json
# Written batch 379: 6 records to sensor_batch_0379_1756182330.json
# Written batch 380: 6 records to sensor_batch_0380_1756182335.json
# Written batch 380: 6 records to sensor_batch_0380_1756182335.json
# Written batch 381: 6 records to sensor_batch_0381_1756182340.json
# Written batch 381: 6 records to sensor_batch_0381_1756182340.json
# Written batch 382: 6 records to sensor_batch_0382_1756182345.json
# Written batch 382: 6 records to sensor_batch_0382_1756182345.json
# Written batch 383: 6 records to sensor_batch_0383_1756182350.json
# Written batch 383: 6 records to sensor_batch_0383_1756182350.json
# Written batch 384: 6 records to sensor_batch_0384_1756182355.json
# Written batch 384: 6 records to sensor_batch_0384_1756182355.json
# Written batch 385: 6 records to sensor_batch_0385_1756182360.json
# Written batch 385: 6 records to sensor_batch_0385_1756182360.json
# Written batch 386: 6 records to sensor_batch_0386_1756182365.json
# Written batch 386: 6 records to sensor_batch_0386_1756182365.json
# Written batch 387: 6 records to sensor_batch_0387_1756182370.json
# Written batch 387: 6 records to sensor_batch_0387_1756182370.json
# Written batch 388: 6 records to sensor_batch_0388_1756182375.json
# Written batch 388: 6 records to sensor_batch_0388_1756182375.json
# Written batch 389: 6 records to sensor_batch_0389_1756182380.json
# Written batch 389: 6 records to sensor_batch_0389_1756182380.json
# Written batch 390: 6 records to sensor_batch_0390_1756182385.json
# Written batch 390: 6 records to sensor_batch_0390_1756182385.json
# Written batch 391: 6 records to sensor_batch_0391_1756182390.json
# Written batch 391: 6 records to sensor_batch_0391_1756182390.json
# Written batch 392: 6 records to sensor_batch_0392_1756182395.json
# Written batch 392: 6 records to sensor_batch_0392_1756182395.json
# Written batch 393: 6 records to sensor_batch_0393_1756182400.json
# Written batch 393: 6 records to sensor_batch_0393_1756182400.json
# Written batch 394: 6 records to sensor_batch_0394_1756182405.json
# Written batch 394: 6 records to sensor_batch_0394_1756182405.json
# Written batch 395: 6 records to sensor_batch_0395_1756182410.json
# Written batch 395: 6 records to sensor_batch_0395_1756182410.json
# Written batch 396: 6 records to sensor_batch_0396_1756182415.json
# Written batch 396: 6 records to sensor_batch_0396_1756182415.json
# Written batch 397: 6 records to sensor_batch_0397_1756182420.json
# Written batch 397: 6 records to sensor_batch_0397_1756182420.json
# Written batch 398: 6 records to sensor_batch_0398_1756182425.json
# Written batch 398: 6 records to sensor_batch_0398_1756182425.json
# Written batch 399: 6 records to sensor_batch_0399_1756182430.json
# Written batch 399: 6 records to sensor_batch_0399_1756182430.json
# Written batch 400: 6 records to sensor_batch_0400_1756182435.json
# Written batch 400: 6 records to sensor_batch_0400_1756182435.json
# Written batch 401: 6 records to sensor_batch_0401_1756182440.json
# Written batch 401: 6 records to sensor_batch_0401_1756182440.json
# Written batch 402: 6 records to sensor_batch_0402_1756182445.json
# Written batch 402: 6 records to sensor_batch_0402_1756182445.json
# Written batch 403: 6 records to sensor_batch_0403_1756182450.json
# Written batch 403: 6 records to sensor_batch_0403_1756182450.json
# Written batch 404: 6 records to sensor_batch_0404_1756182455.json
# Written batch 404: 6 records to sensor_batch_0404_1756182455.json
# Written batch 405: 6 records to sensor_batch_0405_1756182460.json
# Written batch 405: 6 records to sensor_batch_0405_1756182460.json
# Written batch 406: 6 records to sensor_batch_0406_1756182465.json
# Written batch 406: 6 records to sensor_batch_0406_1756182465.json
# Written batch 407: 6 records to sensor_batch_0407_1756182470.json
# Written batch 407: 6 records to sensor_batch_0407_1756182470.json
# Written batch 408: 6 records to sensor_batch_0408_1756182475.json
# Written batch 408: 6 records to sensor_batch_0408_1756182475.json
# Written batch 409: 6 records to sensor_batch_0409_1756182480.json
# Written batch 409: 6 records to sensor_batch_0409_1756182480.json
# Written batch 410: 6 records to sensor_batch_0410_1756182485.json
# Written batch 410: 6 records to sensor_batch_0410_1756182485.json
# Written batch 411: 6 records to sensor_batch_0411_1756182490.json
# Written batch 411: 6 records to sensor_batch_0411_1756182490.json
# Written batch 412: 6 records to sensor_batch_0412_1756182495.json
# Written batch 412: 6 records to sensor_batch_0412_1756182495.json
# Written batch 413: 6 records to sensor_batch_0413_1756182500.json
# Written batch 413: 6 records to sensor_batch_0413_1756182500.json
# Written batch 414: 6 records to sensor_batch_0414_1756182505.json
# Written batch 414: 6 records to sensor_batch_0414_1756182505.json
# Written batch 415: 6 records to sensor_batch_0415_1756182510.json
# Written batch 415: 6 records to sensor_batch_0415_1756182510.json
# Written batch 416: 6 records to sensor_batch_0416_1756182515.json
# Written batch 416: 6 records to sensor_batch_0416_1756182515.json
# Written batch 417: 6 records to sensor_batch_0417_1756182520.json
# Written batch 417: 6 records to sensor_batch_0417_1756182520.json
# Written batch 418: 6 records to sensor_batch_0418_1756182525.json
# Written batch 418: 6 records to sensor_batch_0418_1756182525.json
# Written batch 419: 6 records to sensor_batch_0419_1756182530.json
# Written batch 419: 6 records to sensor_batch_0419_1756182530.json
# Written batch 420: 6 records to sensor_batch_0420_1756182535.json
# Written batch 420: 6 records to sensor_batch_0420_1756182535.json
# Written batch 421: 6 records to sensor_batch_0421_1756182540.json
# Written batch 421: 6 records to sensor_batch_0421_1756182540.json
# Written batch 422: 6 records to sensor_batch_0422_1756182545.json
# Written batch 422: 6 records to sensor_batch_0422_1756182545.json
# Written batch 423: 6 records to sensor_batch_0423_1756182550.json
# Written batch 423: 6 records to sensor_batch_0423_1756182550.json
# Written batch 424: 6 records to sensor_batch_0424_1756182555.json
# Written batch 424: 6 records to sensor_batch_0424_1756182555.json
# Written batch 425: 6 records to sensor_batch_0425_1756182560.json
# Written batch 425: 6 records to sensor_batch_0425_1756182560.json
# Written batch 426: 6 records to sensor_batch_0426_1756182565.json
# Written batch 426: 6 records to sensor_batch_0426_1756182565.json
# Written batch 427: 6 records to sensor_batch_0427_1756182570.json
# Written batch 427: 6 records to sensor_batch_0427_1756182570.json
# Written batch 428: 6 records to sensor_batch_0428_1756182575.json
# Written batch 428: 6 records to sensor_batch_0428_1756182575.json
# Written batch 429: 6 records to sensor_batch_0429_1756182580.json
# Written batch 429: 6 records to sensor_batch_0429_1756182580.json
# Written batch 430: 6 records to sensor_batch_0430_1756182585.json
# Written batch 430: 6 records to sensor_batch_0430_1756182585.json
# Written batch 431: 6 records to sensor_batch_0431_1756182590.json
# Written batch 431: 6 records to sensor_batch_0431_1756182590.json
# Written batch 432: 6 records to sensor_batch_0432_1756182595.json
# Written batch 432: 6 records to sensor_batch_0432_1756182595.json
# Written batch 433: 6 records to sensor_batch_0433_1756182600.json
# Written batch 433: 6 records to sensor_batch_0433_1756182600.json
# Written batch 434: 6 records to sensor_batch_0434_1756182605.json
# Written batch 434: 6 records to sensor_batch_0434_1756182605.json
# Written batch 435: 6 records to sensor_batch_0435_1756182610.json
# Written batch 435: 6 records to sensor_batch_0435_1756182610.json
# Written batch 436: 6 records to sensor_batch_0436_1756182615.json
# Written batch 436: 6 records to sensor_batch_0436_1756182615.json
# Written batch 437: 6 records to sensor_batch_0437_1756182620.json
# Written batch 437: 6 records to sensor_batch_0437_1756182620.json
# Written batch 438: 6 records to sensor_batch_0438_1756182625.json
# Written batch 438: 6 records to sensor_batch_0438_1756182625.json
# Written batch 439: 6 records to sensor_batch_0439_1756182630.json
# Written batch 439: 6 records to sensor_batch_0439_1756182630.json
# Written batch 440: 6 records to sensor_batch_0440_1756182635.json
# Written batch 440: 6 records to sensor_batch_0440_1756182635.json
# Written batch 441: 6 records to sensor_batch_0441_1756182640.json
# Written batch 441: 6 records to sensor_batch_0441_1756182640.json
# Written batch 442: 6 records to sensor_batch_0442_1756182645.json
# Written batch 442: 6 records to sensor_batch_0442_1756182645.json
# Written batch 443: 6 records to sensor_batch_0443_1756182650.json
# Written batch 443: 6 records to sensor_batch_0443_1756182650.json
# Written batch 444: 6 records to sensor_batch_0444_1756182655.json
# Written batch 444: 6 records to sensor_batch_0444_1756182655.json
# Written batch 445: 6 records to sensor_batch_0445_1756182660.json
# Written batch 445: 6 records to sensor_batch_0445_1756182660.json
# Written batch 446: 6 records to sensor_batch_0446_1756182665.json
# Written batch 446: 6 records to sensor_batch_0446_1756182665.json
# Written batch 447: 6 records to sensor_batch_0447_1756182670.json
# Written batch 447: 6 records to sensor_batch_0447_1756182670.json
# Written batch 448: 6 records to sensor_batch_0448_1756182675.json
# Written batch 448: 6 records to sensor_batch_0448_1756182675.json
# Written batch 449: 6 records to sensor_batch_0449_1756182680.json
# Written batch 449: 6 records to sensor_batch_0449_1756182680.json
# Written batch 450: 6 records to sensor_batch_0450_1756182685.json
# Written batch 450: 6 records to sensor_batch_0450_1756182685.json
# Written batch 451: 6 records to sensor_batch_0451_1756182690.json
# Written batch 451: 6 records to sensor_batch_0451_1756182690.json
# Written batch 452: 6 records to sensor_batch_0452_1756182695.json
# Written batch 452: 6 records to sensor_batch_0452_1756182695.json
# Written batch 453: 6 records to sensor_batch_0453_1756182700.json
# Written batch 453: 6 records to sensor_batch_0453_1756182700.json
# Written batch 454: 6 records to sensor_batch_0454_1756182705.json
# Written batch 454: 6 records to sensor_batch_0454_1756182705.json
# Written batch 455: 6 records to sensor_batch_0455_1756182710.json
# Written batch 455: 6 records to sensor_batch_0455_1756182710.json
# Written batch 456: 6 records to sensor_batch_0456_1756182715.json
# Written batch 456: 6 records to sensor_batch_0456_1756182715.json
# Written batch 457: 6 records to sensor_batch_0457_1756182720.json
# Written batch 457: 6 records to sensor_batch_0457_1756182720.json
# Written batch 458: 6 records to sensor_batch_0458_1756182725.json
# Written batch 458: 6 records to sensor_batch_0458_1756182725.json
# Written batch 459: 6 records to sensor_batch_0459_1756182730.json
# Written batch 459: 6 records to sensor_batch_0459_1756182730.json
# Written batch 460: 6 records to sensor_batch_0460_1756182736.json
# Written batch 460: 6 records to sensor_batch_0460_1756182736.json
# Written batch 461: 6 records to sensor_batch_0461_1756182741.json
# Written batch 461: 6 records to sensor_batch_0461_1756182741.json
# Written batch 462: 6 records to sensor_batch_0462_1756182746.json
# Written batch 462: 6 records to sensor_batch_0462_1756182746.json
# Written batch 463: 6 records to sensor_batch_0463_1756182751.json
# Written batch 463: 6 records to sensor_batch_0463_1756182751.json
# Written batch 464: 6 records to sensor_batch_0464_1756182756.json
# Written batch 464: 6 records to sensor_batch_0464_1756182756.json
# Written batch 465: 6 records to sensor_batch_0465_1756182761.json
# Written batch 465: 6 records to sensor_batch_0465_1756182761.json
# Written batch 466: 6 records to sensor_batch_0466_1756182766.json
# Written batch 466: 6 records to sensor_batch_0466_1756182766.json
# Written batch 467: 6 records to sensor_batch_0467_1756182771.json
# Written batch 467: 6 records to sensor_batch_0467_1756182771.json
# Written batch 468: 6 records to sensor_batch_0468_1756182776.json
# Written batch 468: 6 records to sensor_batch_0468_1756182776.json
# Written batch 469: 6 records to sensor_batch_0469_1756182781.json
# Written batch 469: 6 records to sensor_batch_0469_1756182781.json
# Written batch 470: 6 records to sensor_batch_0470_1756182786.json
# Written batch 470: 6 records to sensor_batch_0470_1756182786.json
# Written batch 471: 6 records to sensor_batch_0471_1756182791.json
# Written batch 471: 6 records to sensor_batch_0471_1756182791.json
# Written batch 472: 6 records to sensor_batch_0472_1756182796.json
# Written batch 472: 6 records to sensor_batch_0472_1756182796.json
# Written batch 473: 6 records to sensor_batch_0473_1756182801.json
# Written batch 473: 6 records to sensor_batch_0473_1756182801.json
# Written batch 474: 6 records to sensor_batch_0474_1756182806.json
# Written batch 474: 6 records to sensor_batch_0474_1756182806.json
# Written batch 475: 6 records to sensor_batch_0475_1756182811.json
# Written batch 475: 6 records to sensor_batch_0475_1756182811.json
# Written batch 476: 6 records to sensor_batch_0476_1756182816.json
# Written batch 476: 6 records to sensor_batch_0476_1756182816.json
# Written batch 477: 6 records to sensor_batch_0477_1756182821.json
# Written batch 477: 6 records to sensor_batch_0477_1756182821.json
# Written batch 478: 6 records to sensor_batch_0478_1756182826.json
# Written batch 478: 6 records to sensor_batch_0478_1756182826.json
# Written batch 479: 6 records to sensor_batch_0479_1756182831.json
# Written batch 479: 6 records to sensor_batch_0479_1756182831.json
# Written batch 480: 6 records to sensor_batch_0480_1756182836.json
# Written batch 480: 6 records to sensor_batch_0480_1756182836.json
# Written batch 481: 6 records to sensor_batch_0481_1756182841.json
# Written batch 481: 6 records to sensor_batch_0481_1756182841.json
# Written batch 482: 6 records to sensor_batch_0482_1756182846.json
# Written batch 482: 6 records to sensor_batch_0482_1756182846.json
# Written batch 483: 6 records to sensor_batch_0483_1756182851.json
# Written batch 483: 6 records to sensor_batch_0483_1756182851.json
# Written batch 484: 6 records to sensor_batch_0484_1756182856.json
# Written batch 484: 6 records to sensor_batch_0484_1756182856.json
# Written batch 485: 6 records to sensor_batch_0485_1756182861.json
# Written batch 485: 6 records to sensor_batch_0485_1756182861.json
# Written batch 486: 6 records to sensor_batch_0486_1756182866.json
# Written batch 486: 6 records to sensor_batch_0486_1756182866.json
# Written batch 487: 6 records to sensor_batch_0487_1756182871.json
# Written batch 487: 6 records to sensor_batch_0487_1756182871.json
# Written batch 488: 6 records to sensor_batch_0488_1756182876.json
# Written batch 488: 6 records to sensor_batch_0488_1756182876.json
# Written batch 489: 6 records to sensor_batch_0489_1756182881.json
# Written batch 489: 6 records to sensor_batch_0489_1756182881.json
# Written batch 490: 6 records to sensor_batch_0490_1756182886.json
# Written batch 490: 6 records to sensor_batch_0490_1756182886.json
# Written batch 491: 6 records to sensor_batch_0491_1756182891.json
# Written batch 491: 6 records to sensor_batch_0491_1756182891.json
# Written batch 492: 6 records to sensor_batch_0492_1756182896.json
# Written batch 492: 6 records to sensor_batch_0492_1756182896.json
# Written batch 493: 6 records to sensor_batch_0493_1756182901.json
# Written batch 493: 6 records to sensor_batch_0493_1756182901.json
# Written batch 494: 6 records to sensor_batch_0494_1756182906.json
# Written batch 494: 6 records to sensor_batch_0494_1756182906.json
# Written batch 495: 6 records to sensor_batch_0495_1756182911.json
# Written batch 495: 6 records to sensor_batch_0495_1756182911.json
# Written batch 496: 6 records to sensor_batch_0496_1756182916.json
# Written batch 496: 6 records to sensor_batch_0496_1756182916.json
# Written batch 497: 6 records to sensor_batch_0497_1756182921.json
# Written batch 497: 6 records to sensor_batch_0497_1756182921.json
# Written batch 498: 6 records to sensor_batch_0498_1756182926.json
# Written batch 498: 6 records to sensor_batch_0498_1756182926.json

# %%
# Basic Stream Processing and Analytics
print("Starting basic stream processing...")

# 1. Simple streaming query - show raw data
print("=== 1. Raw Streaming Data ===")

raw_query = enriched_stream \
    .select("sensor_id", "city", "sensor_type", "event_time", "temperature", "humidity") \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .option("numRows", 10) \
    .trigger(processingTime='10 seconds') \
    .start()

print("Raw data streaming query started")

# 2. Real-time aggregations by sensor type
print("\n=== 2. Real-time Aggregations ===")

sensor_aggregations = enriched_stream \
    .filter(col("temperature").isNotNull()) \
    .groupBy("sensor_type", "city") \
    .agg(
        avg("temperature").alias("avg_temperature"),
        max("temperature").alias("max_temperature"),
        min("temperature").alias("min_temperature"),
        avg("humidity").alias("avg_humidity"),
        count("*").alias("reading_count")
    ) \
    .orderBy("sensor_type", "avg_temperature")

agg_query = sensor_aggregations \
    .writeStream \
    .outputMode("complete") \
    .format("console") \
    .option("truncate", False) \
    .trigger(processingTime='15 seconds') \
    .start()

print("Aggregation streaming query started")

# 3. Air quality monitoring (for air quality sensors only)
print("\n=== 3. Air Quality Monitoring ===")

air_quality_alerts = enriched_stream \
    .filter(col("sensor_type") == "air_quality") \
    .filter(col("pm25").isNotNull()) \
    .select(
        "sensor_id", "city", "event_time", "pm25", "pm10", "o3", "no2",
        when(col("pm25") > 35.0, "UNHEALTHY").
        when(col("pm25") > 25.0, "MODERATE").
        otherwise("GOOD").alias("air_quality_status")
    ) \
    .filter(col("pm25") > 20.0)  # Focus on higher pollution readings

air_quality_query = air_quality_alerts \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .option("numRows", 8) \
    .trigger(processingTime='12 seconds') \
    .start()

print("Air quality monitoring query started")

# Let streams run for a bit to show output
print("\nStreaming queries are running...")
print("Raw data: every 10 seconds")
print("Aggregations: every 15 seconds") 
print("Air quality alerts: every 12 seconds")
print("\nLet's watch the streams for 30 seconds...")

time.sleep(30)
# Out:
# Starting basic stream processing...
# === 1. Raw Streaming Data ===
# 25/08/25 23:39:55 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# Raw data streaming query started
#
# === 2. Real-time Aggregations ===
# Aggregation streaming query started
#
# === 3. Air Quality Monitoring ===
# 25/08/25 23:39:55 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 25/08/25 23:39:55 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# Air quality monitoring query started
#
# Streaming queries are running...
# Raw data: every 10 seconds
# Aggregations: every 15 seconds
# Air quality alerts: every 12 seconds
#
# Let's watch the streams for 30 seconds...
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:50|12.3       |53.1    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:39:50|15.9       |94.3    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:39:50|25.9       |66.5    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:39:50|25.7       |37.8    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:39:50|12.5       |72.8    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:39:50|40.8       |33.1    |
# |SEA_007  |Seattle      |air_quality|2025-08-25 23:39:50|-5.4       |60.5    |
# |MIA_008  |Miami        |weather    |2025-08-25 23:39:50|6.8        |82.0    |
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:52|-6.3       |90.1    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:39:52|2.9        |81.6    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# +---------+-----------+-------------------+------+------+------+-----+------------------+
# |sensor_id|city       |event_time         |pm25  |pm10  |o3    |no2  |air_quality_status|
# +---------+-----------+-------------------+------+------+------+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:39:50|111.25|194.01|54.47 |47.02|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:39:50|135.73|13.51 |68.67 |25.49|UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:39:50|128.34|95.13 |23.66 |31.53|UNHEALTHY         |
# |SEA_007  |Seattle    |2025-08-25 23:39:50|122.22|135.71|123.11|83.13|UNHEALTHY         |
# |NYC_001  |New York   |2025-08-25 23:39:52|58.58 |39.86 |100.09|42.34|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:39:52|104.82|138.89|118.02|52.82|UNHEALTHY         |
# +---------+-----------+-------------------+------+------+------+-----+------------------+
#
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:50|12.3       |53.1    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:39:50|15.9       |94.3    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:39:50|25.9       |66.5    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:39:50|25.7       |37.8    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:39:50|12.5       |72.8    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:39:50|40.8       |33.1    |
# |SEA_007  |Seattle      |air_quality|2025-08-25 23:39:50|-5.4       |60.5    |
# |MIA_008  |Miami        |weather    |2025-08-25 23:39:50|6.8        |82.0    |
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:52|-6.3       |90.1    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:39:52|2.9        |81.6    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# +---------+-----------+-------------------+------+------+------+-----+------------------+
# |sensor_id|city       |event_time         |pm25  |pm10  |o3    |no2  |air_quality_status|
# +---------+-----------+-------------------+------+------+------+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:39:50|111.25|194.01|54.47 |47.02|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:39:50|135.73|13.51 |68.67 |25.49|UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:39:50|128.34|95.13 |23.66 |31.53|UNHEALTHY         |
# |SEA_007  |Seattle    |2025-08-25 23:39:50|122.22|135.71|123.11|83.13|UNHEALTHY         |
# |NYC_001  |New York   |2025-08-25 23:39:52|58.58 |39.86 |100.09|42.34|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:39:52|104.82|138.89|118.02|52.82|UNHEALTHY         |
# +---------+-----------+-------------------+------+------+------+-----+------------------+
#
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-----------+-------------+------------------+---------------+---------------+-----------------+-------------+
# |sensor_type|city         |avg_temperature   |max_temperature|min_temperature|avg_humidity     |reading_count|
# +-----------+-------------+------------------+---------------+---------------+-----------------+-------------+
# |air_quality|Seattle      |-5.4              |-5.4           |-5.4           |60.5             |1            |
# |air_quality|New York     |3.0000000000000004|12.3           |-6.3           |71.6             |2            |
# |air_quality|Los Angeles  |9.4               |15.9           |2.9            |87.94999999999999|2            |
# |air_quality|Phoenix      |12.5              |12.5           |12.5           |72.8             |1            |
# |weather    |Miami        |6.8               |6.8            |6.8            |82.0             |1            |
# |weather    |Houston      |25.7              |25.7           |25.7           |37.8             |1            |
# |weather    |Chicago      |25.9              |25.9           |25.9           |66.5             |1            |
# |weather    |San Francisco|40.8              |40.8           |40.8           |33.1             |1            |
# +-----------+-------------+------------------+---------------+---------------+-----------------+-------------+
#
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-----------+-------------+------------------+---------------+---------------+-----------------+-------------+
# |sensor_type|city         |avg_temperature   |max_temperature|min_temperature|avg_humidity     |reading_count|
# +-----------+-------------+------------------+---------------+---------------+-----------------+-------------+
# |air_quality|Seattle      |-5.4              |-5.4           |-5.4           |60.5             |1            |
# |air_quality|New York     |3.0000000000000004|12.3           |-6.3           |71.6             |2            |
# |air_quality|Los Angeles  |9.4               |15.9           |2.9            |87.94999999999999|2            |
# |air_quality|Phoenix      |12.5              |12.5           |12.5           |72.8             |1            |
# |weather    |Miami        |6.8               |6.8            |6.8            |82.0             |1            |
# |weather    |Houston      |25.7              |25.7           |25.7           |37.8             |1            |
# |weather    |Chicago      |25.9              |25.9           |25.9           |66.5             |1            |
# |weather    |San Francisco|40.8              |40.8           |40.8           |33.1             |1            |
# +-----------+-------------+------------------+---------------+---------------+-----------------+-------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:53|14.9       |67.3    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:40:09|-3.1       |43.8    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:40:13|31.2       |34.5    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:39:57|11.9       |51.0    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:39:21|23.0       |41.1    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:39:59|24.3       |26.8    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-----------+-------------------+------+-----+------+-----+------------------+
# |sensor_id|city       |event_time         |pm25  |pm10 |o3    |no2  |air_quality_status|
# +---------+-----------+-------------------+------+-----+------+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:39:53|107.98|86.06|151.6 |42.18|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:40:09|97.97 |49.54|68.92 |49.9 |UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:39:21|97.51 |64.94|123.32|75.98|UNHEALTHY         |
# +---------+-----------+-------------------+------+-----+------+-----+------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:53|14.9       |67.3    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:40:09|-3.1       |43.8    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:40:13|31.2       |34.5    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:39:57|11.9       |51.0    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:39:21|23.0       |41.1    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:39:59|24.3       |26.8    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-----------+-------------------+------+-----+------+-----+------------------+
# |sensor_id|city       |event_time         |pm25  |pm10 |o3    |no2  |air_quality_status|
# +---------+-----------+-------------------+------+-----+------+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:39:53|107.98|86.06|151.6 |42.18|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:40:09|97.97 |49.54|68.92 |49.9 |UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:39:21|97.51 |64.94|123.32|75.98|UNHEALTHY         |
# +---------+-----------+-------------------+------+-----+------+-----+------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |sensor_type|city         |avg_temperature   |max_temperature|min_temperature|avg_humidity      |reading_count|
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |air_quality|Seattle      |-5.4              |-5.4           |-5.4           |60.5              |1            |
# |air_quality|Los Angeles  |5.233333333333333 |15.9           |-3.1           |73.23333333333333 |3            |
# |air_quality|New York     |6.966666666666668 |14.9           |-6.3           |70.16666666666667 |3            |
# |air_quality|Phoenix      |17.75             |23.0           |12.5           |56.95             |2            |
# |weather    |Miami        |6.8               |6.8            |6.8            |82.0              |1            |
# |weather    |Houston      |18.8              |25.7           |11.9           |44.4              |2            |
# |weather    |Chicago      |28.549999999999997|31.2           |25.9           |50.5              |2            |
# |weather    |San Francisco|32.55             |40.8           |24.3           |29.950000000000003|2            |
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |sensor_type|city         |avg_temperature   |max_temperature|min_temperature|avg_humidity      |reading_count|
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |air_quality|Seattle      |-5.4              |-5.4           |-5.4           |60.5              |1            |
# |air_quality|Los Angeles  |5.233333333333333 |15.9           |-3.1           |73.23333333333333 |3            |
# |air_quality|New York     |6.966666666666668 |14.9           |-6.3           |70.16666666666667 |3            |
# |air_quality|Phoenix      |17.75             |23.0           |12.5           |56.95             |2            |
# |weather    |Miami        |6.8               |6.8            |6.8            |82.0              |1            |
# |weather    |Houston      |18.8              |25.7           |11.9           |44.4              |2            |
# |weather    |Chicago      |28.549999999999997|31.2           |25.9           |50.5              |2            |
# |weather    |San Francisco|32.55             |40.8           |24.3           |29.950000000000003|2            |
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:40:11|34.2       |80.7    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:39:45|26.3       |52.8    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:39:43|27.3       |43.9    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:39:54|3.9        |49.6    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:39:38|7.8        |42.0    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:40:00|6.4        |33.6    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:40:11|34.2       |80.7    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:39:45|26.3       |52.8    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:39:43|27.3       |43.9    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:39:54|3.9        |49.6    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:39:38|7.8        |42.0    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:40:00|6.4        |33.6    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---------+-----------+-------------------+-----+------+-----+-----+------------------+
# |sensor_id|city       |event_time         |pm25 |pm10  |o3   |no2  |air_quality_status|
# +---------+-----------+-------------------+-----+------+-----+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:40:11|71.27|43.31 |69.98|83.71|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:39:45|69.22|57.62 |38.72|23.02|UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:39:38|84.22|157.02|54.24|88.04|UNHEALTHY         |
# +---------+-----------+-------------------+-----+------+-----+-----+------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---------+-----------+-------------------+-----+------+-----+-----+------------------+
# |sensor_id|city       |event_time         |pm25 |pm10  |o3   |no2  |air_quality_status|
# +---------+-----------+-------------------+-----+------+-----+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:40:11|71.27|43.31 |69.98|83.71|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:39:45|69.22|57.62 |38.72|23.02|UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:39:38|84.22|157.02|54.24|88.04|UNHEALTHY         |
# +---------+-----------+-------------------+-----+------+-----+-----+------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |sensor_type|city         |avg_temperature   |max_temperature|min_temperature|avg_humidity      |reading_count|
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |air_quality|Seattle      |-5.4              |-5.4           |-5.4           |60.5              |1            |
# |air_quality|Los Angeles  |10.5              |26.3           |-3.1           |68.125            |4            |
# |air_quality|New York     |13.775000000000002|34.2           |-6.3           |72.8              |4            |
# |air_quality|Phoenix      |14.433333333333332|23.0           |7.8            |51.96666666666667 |3            |
# |weather    |Miami        |6.8               |6.8            |6.8            |82.0              |1            |
# |weather    |Houston      |13.833333333333334|25.7           |3.9            |46.13333333333333 |3            |
# |weather    |San Francisco|23.833333333333332|40.8           |6.4            |31.166666666666668|3            |
# |weather    |Chicago      |28.13333333333333 |31.2           |25.9           |48.300000000000004|3            |
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |sensor_type|city         |avg_temperature   |max_temperature|min_temperature|avg_humidity      |reading_count|
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
# |air_quality|Seattle      |-5.4              |-5.4           |-5.4           |60.5              |1            |
# |air_quality|Los Angeles  |10.5              |26.3           |-3.1           |68.125            |4            |
# |air_quality|New York     |13.775000000000002|34.2           |-6.3           |72.8              |4            |
# |air_quality|Phoenix      |14.433333333333332|23.0           |7.8            |51.96666666666667 |3            |
# |weather    |Miami        |6.8               |6.8            |6.8            |82.0              |1            |
# |weather    |Houston      |13.833333333333334|25.7           |3.9            |46.13333333333333 |3            |
# |weather    |San Francisco|23.833333333333332|40.8           |6.4            |31.166666666666668|3            |
# |weather    |Chicago      |28.13333333333333 |31.2           |25.9           |48.300000000000004|3            |
# +-----------+-------------+------------------+---------------+---------------+------------------+-------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:34|38.5       |25.8    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:40:24|-3.7       |58.4    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:39:37|16.2       |44.0    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:40:28|8.6        |46.2    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:40:07|-3.0       |83.4    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:39:53|1.1        |57.1    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +---------+-------------+-----------+-------------------+-----------+--------+
# |sensor_id|city         |sensor_type|event_time         |temperature|humidity|
# +---------+-------------+-----------+-------------------+-----------+--------+
# |NYC_001  |New York     |air_quality|2025-08-25 23:39:34|38.5       |25.8    |
# |LA_002   |Los Angeles  |air_quality|2025-08-25 23:40:24|-3.7       |58.4    |
# |CHI_003  |Chicago      |weather    |2025-08-25 23:39:37|16.2       |44.0    |
# |HOU_004  |Houston      |weather    |2025-08-25 23:40:28|8.6        |46.2    |
# |PHX_005  |Phoenix      |air_quality|2025-08-25 23:40:07|-3.0       |83.4    |
# |SF_006   |San Francisco|weather    |2025-08-25 23:39:53|1.1        |57.1    |
# +---------+-------------+-----------+-------------------+-----------+--------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +---------+-----------+-------------------+-----+-----+------+-----+------------------+
# |sensor_id|city       |event_time         |pm25 |pm10 |o3    |no2  |air_quality_status|
# +---------+-----------+-------------------+-----+-----+------+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:39:34|77.57|77.67|116.98|35.21|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:40:24|109.1|62.42|145.69|66.82|UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:40:07|51.74|84.39|107.68|87.45|UNHEALTHY         |
# +---------+-----------+-------------------+-----+-----+------+-----+------------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +---------+-----------+-------------------+-----+-----+------+-----+------------------+
# |sensor_id|city       |event_time         |pm25 |pm10 |o3    |no2  |air_quality_status|
# +---------+-----------+-------------------+-----+-----+------+-----+------------------+
# |NYC_001  |New York   |2025-08-25 23:39:34|77.57|77.67|116.98|35.21|UNHEALTHY         |
# |LA_002   |Los Angeles|2025-08-25 23:40:24|109.1|62.42|145.69|66.82|UNHEALTHY         |
# |PHX_005  |Phoenix    |2025-08-25 23:40:07|51.74|84.39|107.68|87.45|UNHEALTHY         |
# +---------+-----------+-------------------+-----+-----+------+-----+------------------+

# %%
# Windowing Operations and Stream Management
print("=== Stream Management and Windowing ===")

# Stop previous queries after demonstration
print("Stopping previous streaming queries...")
for stream in spark.streams.active:
    print(f"Stopping stream: {stream.name}")
    stream.stop()

print("All streams stopped")

# Wait for clean shutdown
time.sleep(2)

# Advanced windowing example
print("\n=== 4. Windowing Operations ===")

# Create windowed aggregations (5-minute tumbling windows)
windowed_analytics = enriched_stream \
    .filter(col("temperature").isNotNull()) \
    .withWatermark("event_time", "2 minutes") \
    .groupBy(
        window(col("event_time"), "5 minutes"),
        col("city"),
        col("sensor_type")
    ) \
    .agg(
        avg("temperature").alias("avg_temp"),
        max("temperature").alias("max_temp"),
        min("temperature").alias("min_temp"),
        count("*").alias("reading_count"),
        stddev("temperature").alias("temp_stddev")
    ) \
    .select(
        col("window.start").alias("window_start"),
        col("window.end").alias("window_end"),
        "city", "sensor_type", "avg_temp", "max_temp", "min_temp", 
        "reading_count", "temp_stddev"
    )

# Start windowed query
window_query = windowed_analytics \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .trigger(processingTime='20 seconds') \
    .start()

print("Windowed analytics query started (5-minute windows)")

# Real-time anomaly detection
print("\n=== 5. Real-time Anomaly Detection ===")

anomaly_detection = enriched_stream \
    .filter(col("sensor_type") == "air_quality") \
    .filter(col("pm25").isNotNull()) \
    .select(
        "sensor_id", "city", "event_time", "pm25", "pm10", "temperature",
        when(col("pm25") > 100, "HAZARDOUS") \
        .when(col("pm25") > 55, "UNHEALTHY") \
        .when(col("pm25") > 35, "MODERATE") \
        .otherwise("GOOD").alias("air_quality_level"),
        (col("pm25") > 75).alias("high_pollution_alert")
    ) \
    .filter(col("pm25") > 50)  # Only show concerning readings

anomaly_query = anomaly_detection \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .option("numRows", 5) \
    .trigger(processingTime='15 seconds') \
    .start()

print("Anomaly detection query started")

# Stream statistics
print("\n=== 6. Stream Statistics ===")
time.sleep(25)  # Let streams run

print("\nActive streaming queries:")
for stream in spark.streams.active:
    print(f"- {stream.name}: {stream.status}")
    
print("\nStreaming demonstration complete!")
print("All streaming concepts covered: basic processing, aggregations, windowing, and anomaly detection")
# Out:
# === Stream Management and Windowing ===
# Stopping previous streaming queries...
# Stopping stream: None
# Stopping stream: None
# Stopping stream: None
# All streams stopped
# 25/08/25 23:40:25 WARN DAGScheduler: Failed to cancel job group 87c5dce7-d8af-4e3d-94d5-8e24db60e623. Cannot find active jobs for it.
# 25/08/25 23:40:25 WARN DAGScheduler: Failed to cancel job group 87c5dce7-d8af-4e3d-94d5-8e24db60e623. Cannot find active jobs for it.
# 25/08/25 23:40:25 WARN DAGScheduler: Failed to cancel job group 7606b897-1cd9-449a-98bc-e92d0f30bbda. Cannot find active jobs for it.
# 25/08/25 23:40:25 WARN DAGScheduler: Failed to cancel job group 7606b897-1cd9-449a-98bc-e92d0f30bbda. Cannot find active jobs for it.
# 25/08/25 23:40:25 WARN DAGScheduler: Failed to cancel job group e48ca74d-3c58-4316-be78-4cfee78f65ab. Cannot find active jobs for it.
# 25/08/25 23:40:25 WARN DAGScheduler: Failed to cancel job group e48ca74d-3c58-4316-be78-4cfee78f65ab. Cannot find active jobs for it.
# === 4. Windowing Operations ===
# Windowed analytics query started (5-minute windows)
#
# === 5. Real-time Anomaly Detection ===
# 25/08/25 23:40:27 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 25/08/25 23:40:27 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# Anomaly detection query started
#
# === 6. Stream Statistics ===
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------+-----------+-------------------+------+------+-----------+-----------------+--------------------+
# |sensor_id|city       |event_time         |pm25  |pm10  |temperature|air_quality_level|high_pollution_alert|
# +---------+-----------+-------------------+------+------+-----------+-----------------+--------------------+
# |NYC_001  |New York   |2025-08-25 23:39:50|111.25|194.01|12.3       |HAZARDOUS        |true                |
# |LA_002   |Los Angeles|2025-08-25 23:39:50|135.73|13.51 |15.9       |HAZARDOUS        |true                |
# |PHX_005  |Phoenix    |2025-08-25 23:39:50|128.34|95.13 |12.5       |HAZARDOUS        |true                |
# |SEA_007  |Seattle    |2025-08-25 23:39:50|122.22|135.71|-5.4       |HAZARDOUS        |true                |
# |NYC_001  |New York   |2025-08-25 23:39:52|58.58 |39.86 |-6.3       |UNHEALTHY        |false               |
# +---------+-----------+-------------------+------+------+-----------+-----------------+--------------------+
# only showing top 5 rows
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------+-----------+-------------------+------+------+-----------+-----------------+--------------------+
# |sensor_id|city       |event_time         |pm25  |pm10  |temperature|air_quality_level|high_pollution_alert|
# +---------+-----------+-------------------+------+------+-----------+-----------------+--------------------+
# |NYC_001  |New York   |2025-08-25 23:39:50|111.25|194.01|12.3       |HAZARDOUS        |true                |
# |LA_002   |Los Angeles|2025-08-25 23:39:50|135.73|13.51 |15.9       |HAZARDOUS        |true                |
# |PHX_005  |Phoenix    |2025-08-25 23:39:50|128.34|95.13 |12.5       |HAZARDOUS        |true                |
# |SEA_007  |Seattle    |2025-08-25 23:39:50|122.22|135.71|-5.4       |HAZARDOUS        |true                |
# |NYC_001  |New York   |2025-08-25 23:39:52|58.58 |39.86 |-6.3       |UNHEALTHY        |false               |
# +---------+-----------+-------------------+------+------+-----------+-----------------+--------------------+
# only showing top 5 rows
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# |window_start|window_end|city|sensor_type|avg_temp|max_temp|min_temp|reading_count|temp_stddev|
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
#
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# |window_start|window_end|city|sensor_type|avg_temp|max_temp|min_temp|reading_count|temp_stddev|
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-----------+-------------------+------+-----+-----------+-----------------+--------------------+
# |sensor_id|city       |event_time         |pm25  |pm10 |temperature|air_quality_level|high_pollution_alert|
# +---------+-----------+-------------------+------+-----+-----------+-----------------+--------------------+
# |NYC_001  |New York   |2025-08-25 23:39:53|107.98|86.06|14.9       |HAZARDOUS        |true                |
# |LA_002   |Los Angeles|2025-08-25 23:40:09|97.97 |49.54|-3.1       |UNHEALTHY        |true                |
# |PHX_005  |Phoenix    |2025-08-25 23:39:21|97.51 |64.94|23.0       |UNHEALTHY        |true                |
# +---------+-----------+-------------------+------+-----+-----------+-----------------+--------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-----------+-------------------+------+-----+-----------+-----------------+--------------------+
# |sensor_id|city       |event_time         |pm25  |pm10 |temperature|air_quality_level|high_pollution_alert|
# +---------+-----------+-------------------+------+-----+-----------+-----------------+--------------------+
# |NYC_001  |New York   |2025-08-25 23:39:53|107.98|86.06|14.9       |HAZARDOUS        |true                |
# |LA_002   |Los Angeles|2025-08-25 23:40:09|97.97 |49.54|-3.1       |UNHEALTHY        |true                |
# |PHX_005  |Phoenix    |2025-08-25 23:39:21|97.51 |64.94|23.0       |UNHEALTHY        |true                |
# +---------+-----------+-------------------+------+-----+-----------+-----------------+--------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# |window_start|window_end|city|sensor_type|avg_temp|max_temp|min_temp|reading_count|temp_stddev|
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# |window_start|window_end|city|sensor_type|avg_temp|max_temp|min_temp|reading_count|temp_stddev|
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
# +------------+----------+----+-----------+--------+--------+--------+-------------+-----------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---------+-----------+-------------------+-----+------+-----------+-----------------+--------------------+
# |sensor_id|city       |event_time         |pm25 |pm10  |temperature|air_quality_level|high_pollution_alert|
# +---------+-----------+-------------------+-----+------+-----------+-----------------+--------------------+
# |NYC_001  |New York   |2025-08-25 23:40:11|71.27|43.31 |34.2       |UNHEALTHY        |false               |
# |LA_002   |Los Angeles|2025-08-25 23:39:45|69.22|57.62 |26.3       |UNHEALTHY        |false               |
# |PHX_005  |Phoenix    |2025-08-25 23:39:38|84.22|157.02|7.8        |UNHEALTHY        |true                |
# +---------+-----------+-------------------+-----+------+-----------+-----------------+--------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---------+-----------+-------------------+-----+------+-----------+-----------------+--------------------+
# |sensor_id|city       |event_time         |pm25 |pm10  |temperature|air_quality_level|high_pollution_alert|
# +---------+-----------+-------------------+-----+------+-----------+-----------------+--------------------+
# |NYC_001  |New York   |2025-08-25 23:40:11|71.27|43.31 |34.2       |UNHEALTHY        |false               |
# |LA_002   |Los Angeles|2025-08-25 23:39:45|69.22|57.62 |26.3       |UNHEALTHY        |false               |
# |PHX_005  |Phoenix    |2025-08-25 23:39:38|84.22|157.02|7.8        |UNHEALTHY        |true                |
# +---------+-----------+-------------------+-----+------+-----------+-----------------+--------------------+
#
#
# Active streaming queries:
# - None: {'message': 'Waiting for next trigger', 'isDataAvailable': True, 'isTriggerActive': False}
# - None: {'message': 'Waiting for next trigger', 'isDataAvailable': True, 'isTriggerActive': False}
#
# Streaming demonstration complete!
# All streaming concepts covered: basic processing, aggregations, windowing, and anomaly detection
#
# Active streaming queries:
# - None: {'message': 'Waiting for next trigger', 'isDataAvailable': True, 'isTriggerActive': False}
# - None: {'message': 'Waiting for next trigger', 'isDataAvailable': True, 'isTriggerActive': False}
#
# Streaming demonstration complete!
# All streaming concepts covered: basic processing, aggregations, windowing, and anomaly detection

# %%
# Module 7 Summary and Cleanup
print("=== Module 7: Structured Streaming - Complete! ===")

# Stop all active streaming queries
print("\nCleaning up streaming queries...")
for stream in spark.streams.active:
    print(f"Stopping: {stream.name if stream.name else 'Unnamed Query'}")
    stream.stop()

print("All streaming queries stopped")

# Summary of what we accomplished
print("\n" + "="*60)
print("MODULE 7 ACCOMPLISHMENTS")
print("="*60)

print("\n✅ STREAMING FUNDAMENTALS")
print("   • Set up Structured Streaming environment")
print("   • Created real-time data sources with realistic IoT sensor data")
print("   • Implemented live data simulator for continuous streaming")

print("\n✅ STREAM PROCESSING PATTERNS")
print("   • Basic transformations and filtering")
print("   • Real-time aggregations by sensor type and location")
print("   • Time-based analytics with event time processing")

print("\n✅ WINDOWING OPERATIONS")
print("   • Implemented 5-minute tumbling windows")
print("   • Watermark handling for late-arriving data")
print("   • Statistical aggregations over time windows")

print("\n✅ REAL-TIME ANALYTICS")
print("   • Air quality monitoring with threshold alerts") 
print("   • Anomaly detection for pollution levels")
print("   • Multi-query streaming architecture")

print("\n✅ PRODUCTION FEATURES")
print("   • Checkpoint management and fault tolerance")
print("   • Multiple output modes (append, complete)")
print("   • Proper stream lifecycle management")

print("\n" + "="*60)
print("STREAMING METRICS ACHIEVED")
print("="*60)

print(f"\n📊 Data Processing:")
print(f"   • Processed sensor data from 8 major cities")
print(f"   • Multiple data types: air quality & weather sensors")
print(f"   • Real-time latency: 5-20 second processing intervals")

print(f"\n📈 Analytics Capabilities:")
print(f"   • Raw data streaming")
print(f"   • Aggregated analytics")
print(f"   • Windowed time-series analysis")
print(f"   • Real-time anomaly detection")

print(f"\n⚡ Performance Features:")
print(f"   • Structured Streaming with optimized triggers")
print(f"   • Watermark-based late data handling")
print(f"   • Multiple concurrent streaming queries")

print("\n" + "="*60)
print("NEXT STEPS - MODULE 8 OPTIONS")
print("="*60)

print("\n🚀 Potential Module 8 Topics:")
print("   1. Advanced ML Integration - Real-time model serving")
print("   2. Graph Analytics - Social network & relationship analysis")  
print("   3. Production Deployment - Docker, Kubernetes, monitoring")
print("   4. External Integrations - Kafka, databases, cloud services")
print("   5. Performance Optimization - Advanced tuning & scaling")

print("\n🎯 Streaming Analytics Mastery Complete!")
print("Ready for production-grade real-time data processing!")

# Clean up temporary directories
import shutil
try:
    shutil.rmtree("/tmp/streaming_data", ignore_errors=True)
    print("\n🧹 Temporary streaming data cleaned up")
except:
    pass

print("\n" + "="*60)
# Out:
# === Module 7: Structured Streaming - Complete! ===
#
# Cleaning up streaming queries...
# Stopping: Unnamed Query
# Stopping: Unnamed Query
# All streaming queries stopped
#
# ============================================================
# MODULE 7 ACCOMPLISHMENTS
# ============================================================
#
# ✅ STREAMING FUNDAMENTALS
#    • Set up Structured Streaming environment
#    • Created real-time data sources with realistic IoT sensor data
#    • Implemented live data simulator for continuous streaming
#
# ✅ STREAM PROCESSING PATTERNS
#    • Basic transformations and filtering
#    • Real-time aggregations by sensor type and location
#    • Time-based analytics with event time processing
#
# ✅ WINDOWING OPERATIONS
#    • Implemented 5-minute tumbling windows
#    • Watermark handling for late-arriving data
#    • Statistical aggregations over time windows
#
# ✅ REAL-TIME ANALYTICS
#    • Air quality monitoring with threshold alerts
#    • Anomaly detection for pollution levels
#    • Multi-query streaming architecture
#
# ✅ PRODUCTION FEATURES
#    • Checkpoint management and fault tolerance
#    • Multiple output modes (append, complete)
#    • Proper stream lifecycle management
#
# ============================================================
# STREAMING METRICS ACHIEVED
# ============================================================
#
# 📊 Data Processing:
#    • Processed sensor data from 8 major cities
#    • Multiple data types: air quality & weather sensors
#    • Real-time latency: 5-20 second processing intervals
#
# 📈 Analytics Capabilities:
#    • Raw data streaming
#    • Aggregated analytics
#    • Windowed time-series analysis
#    • Real-time anomaly detection
#
# ⚡ Performance Features:
#    • Structured Streaming with optimized triggers
#    • Watermark-based late data handling
#    • Multiple concurrent streaming queries
#
# ============================================================
# NEXT STEPS - MODULE 8 OPTIONS
# ============================================================
#
# 🚀 Potential Module 8 Topics:
#    1. Advanced ML Integration - Real-time model serving
#    2. Graph Analytics - Social network & relationship analysis
#    3. Production Deployment - Docker, Kubernetes, monitoring
#    4. External Integrations - Kafka, databases, cloud services
#    5. Performance Optimization - Advanced tuning & scaling
#
# 🎯 Streaming Analytics Mastery Complete!
# Ready for production-grade real-time data processing!
#
# 🧹 Temporary streaming data cleaned up
#
# ============================================================
# 25/08/25 23:40:53 WARN DAGScheduler: Failed to cancel job group 758e1d6b-8871-4dce-ad70-098b901582a3. Cannot find active jobs for it.
# 25/08/25 23:40:53 WARN DAGScheduler: Failed to cancel job group 758e1d6b-8871-4dce-ad70-098b901582a3. Cannot find active jobs for it.
# 25/08/25 23:40:53 WARN DAGScheduler: Failed to cancel job group 2b08205a-06db-4f12-9780-42338886d025. Cannot find active jobs for it.
# 25/08/25 23:40:53 WARN DAGScheduler: Failed to cancel job group 2b08205a-06db-4f12-9780-42338886d025. Cannot find active jobs for it.
